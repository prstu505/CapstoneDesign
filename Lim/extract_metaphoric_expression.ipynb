# %%
import re
from kiwipiepy import Kiwi
import os
import json

PATH1 = './data/sentence_tokenize'
PATH2 = './data/pos_tokenize'
PATH3 = './data/extract_aux'
KIWI = Kiwi(num_workers=2, load_default_dict=True, model_type='knlm')

# 괄호 안의 내용과 바로 앞의 내용이 같을 경우 괄호 부분 삭제 e.g., 이념(이념)
def remove_ss(sentence) :
    p = re.compile(r'[[|{|()}].+?[]|}|)]')

    result = ''
    m = re.search(p, sentence)
    while m is not None : 
        in_ss = sentence[m.start()+1:m.end()-1]
        front_ss = sentence[m.start()-len(in_ss):m.start()]
        if in_ss == front_ss :
            result = result + sentence[:m.start()]
        sentence = sentence[m.end():]
        m = re.search(p, sentence)
    result = result + sentence

    return result

# path의 있는 json 파일들을 불러와 사전형태로 변환하고 리스트 형태로 반환
def load_writings(path) :
    result = []
    for file_name in os.listdir(path) :
        print('load file:\t' + file_name)
        file = open(path + '/' + file_name, 'r', encoding='utf-8')
        result.append(json.load(file))
        file.close()
    return result

# 파일 저장을 위해 토큰들을 사전의 리스트로 변환
def tokens_to_list_of_dict(tokens) :
    result = []
    for token in tokens : 
        result.append({
            'form':token[0], 
            'tag':token[1], 
            'start':token[2], 
            'len':token[3]
        })
    return result

# %%
# load pos tokenize 
writings = load_writings(PATH1)
# Out:
# load file:	SOUR001103&&& 독립신문 창간호 논설.json
# load file:	SOUR001276&&& 옛날 꿈은창백하더이다.json
# load file:	SOUR001379&&& 백팔번뇌 (시조집).json
# load file:	SOUR001427&&& 날개.json
# load file:	SOUR001439&&& 국경의 밤.json
# load file:	SOUR001450&&& 해(해)에게서 소년에게.json
# load file:	SOUR001456&&& 무정(무정).json
# load file:	SOUR001477&&& 을지문덕 (을지문덕).json
# load file:	SOUR001478&&& 이순신전(李순신전).json
# load file:	SOUR001479&&& 최도통전(최도통전).json
# load file:	SOUR001520&&& 감자.json
# load file:	SOUR001521&&& 배따라기.json
# load file:	SOUR001522&&& 상록수 (상록수).json
# load file:	SOUR001547&&& 백치 아다다.json
# load file:	SOUR001548&&& 운수 좋은 날.json
# load file:	SOUR001549&&& 물레방아.json
# load file:	SOUR001550&&& 표본실의 청개구리.json
# load file:	SOUR001561&&& 진달래꽃 (시집).json
# load file:	SOUR001614&&& 빈처 (빈처).json
# load file:	SOUR001615&&& 술 권하는 사회.json
# load file:	SOUR001616&&& B사감과 러브레터.json
# load file:	SOUR001641&&& 메밀꽃 필 무렵.json
# load file:	SOUR001642&&& 동백꽃.json
# load file:	SOUR001647&&& 따라지.json
# load file:	SOUR001648&&& 운현궁의 봄.json
# load file:	SOUR001649&&& 탁류(탁류).json
# load file:	SOUR001652&&& 무영탑 (무영탑).json
# load file:	SOUR001658&&& 뽕.json
# load file:	SOUR001659&&& 벙어리 삼용이.json
# load file:	SOUR001660&&& 나는 왕이로소이다.json
# load file:	SOUR001661&&& 빼앗긴 들에도 봄은 오는가.json
# load file:	SOUR001662&&& 붉은 산.json
# load file:	SOUR001663&&& 발가락이 닮았다.json
# load file:	SOUR001664&&& 광염 소나타.json
# load file:	SOUR001665&&& 광화사(광화사).json
# load file:	SOUR001671&&& 약한 자의 슬픔.json
# load file:	SOUR001672&&& 태형.json
# load file:	SOUR001673&&& 성암[성암]의 길.json
# load file:	SOUR001674&&& 무명 (무명).json
# load file:	SOUR001675&&& 소년의 비애.json
# load file:	SOUR001676&&& 어린 벗에게.json
# load file:	SOUR001677&&& 흙.json
# load file:	SOUR001679&&& 계집 하인.json
# load file:	SOUR001680&&& 소낙비.json
# load file:	SOUR001681&&& 산골나그네.json
# load file:	SOUR001682&&& 금 따는 콩밭.json
# load file:	SOUR001683&&& 산골.json
# load file:	SOUR001684&&& 만무방(만무방).json
# load file:	SOUR001685&&& 봄봄.json
# load file:	SOUR001695&&& 두 파산(파산).json
# load file:	SOUR001696&&& 삼대(삼대).json
# load file:	SOUR001704&&& 봉별기(봉별기).json
# load file:	SOUR001713&&& 논 이야기.json
# load file:	SOUR001714&&& 태평천하(태평천하).json
# load file:	SOUR001715&&& 레디 메이드 인생.json
# load file:	SOUR001716&&& 치숙 (치숙).json
# load file:	SOUR001717&&& 새 길로.json
# load file:	SOUR001723&&& 흑치상지.json
# load file:	SOUR001725&&& 김연실전 (금연실전).json
# load file:	SOUR001726&&& 을지문덕.json
# load file:	SOUR001738&&& 하늘과 바람과 별과 시 (시집).json
# load file:	SOUR001740&&& 일설 춘향전 (일설 춘향전).json
# load file:	SOUR001760&&& 사(사)의 찬미(찬미).json
# load file:	SOUR001761&&& 님의 침묵 (시집).json
# load file:	SOUR001762&&& 단종애사 (단종애사).json
# load file:	SOUR001763&&& 경영 (경영).json
# load file:	SOUR001764&&& 원효대사 (원효대사).json
# load file:	SOUR001767&&& 원고료 이백원 (원고료 이백원).json
# load file:	SOUR001768&&& 봄은 가더이다.json
# load file:	SOUR001769&&& 백조(백조)는 흐르는데 별 하나 나 하나.json
# load file:	SOUR001770&&& 좌평(좌평) 성충(성충).json
# load file:	SOUR001771&&& 부자 (부자).json
# load file:	SOUR001772&&& 소금.json
# load file:	SOUR001773&&& 지하촌 (지하촌).json
# load file:	SOUR001774&&& 어둠.json
# load file:	SOUR001775&&& 낙엽을 태우면서.json
# load file:	SOUR001776&&& 마음에 남는 풍경(풍경).json
# load file:	SOUR001777&&& 적빈 (적빈).json
# load file:	SOUR001778&&& 청춘 (청춘).json
# load file:	SOUR001780&&& 돈 (돈).json
# load file:	SOUR001781&&& 화분(화분).json
# load file:	SOUR001782&&& 벽공무한 (벽공무한).json
# load file:	SOUR001783&&& 포플라나무 예찬.json
# load file:	SOUR001792&&& 김유정(금유정).json
# load file:	SOUR001793&&& 산촌여정 (산촌여정).json
# load file:	SOUR001838&&& 나의 침실(침실)로.json
# load file:	SOUR001839&&& 최서방 (최서방).json
# load file:	SOUR001840&&& 유앵기 (유앵기).json
# load file:	SOUR001841&&& 신기루 (신기루).json
# load file:	SOUR001842&&& 별을 헨다.json
# load file:	SOUR001843&&& 병풍(병풍)에 그린 닭이.json
# load file:	SOUR001846&&& 남(남)으로 창(창)을 내겠소.json
# load file:	SOUR001847&&& 오뇌(오뇌)의 무도(무도) (시집).json
# load file:	SOUR001848&&& 해파리의 노래 (시집).json
# load file:	SOUR001849&&& 삼수갑산 (삼수갑산).json
# load file:	SOUR001850&&& 청춘 예찬 (청춘례찬).json
# load file:	SOUR001851&&& 떠나가는 배.json
# load file:	SOUR001852&&& 싸늘한 이마.json
# load file:	SOUR001853&&& 이상한 샘물.json
# load file:	SOUR001854&&& 나비의 꿈.json
# load file:	SOUR001855&&& 금도끼.json
# load file:	SOUR001856&&& 4월 그믐날 밤.json
# load file:	SOUR001857&&& 선물(선물) 아닌 선물(선물).json
# load file:	SOUR001858&&& 시골쥐 서울 구경.json
# load file:	SOUR001859&&& 욕심쟁이 땅차지.json
# load file:	SOUR001860&&& 호랑이 형님.json
# load file:	SOUR001861&&& 만년 셔츠.json
# load file:	SOUR001862&&& 꼬부랑 할머니.json
# load file:	SOUR001863&&& 털보 장사.json
# load file:	SOUR001864&&& 공원정조 (공원정조).json
# load file:	SOUR001865&&& 뭉게구름의 비밀(비밀).json
# load file:	SOUR001866&&& 어린이 찬미(찬미).json
# load file:	SOUR001867&&& 사라지지 않는 기억.json
# load file:	SOUR001868&&& 없는 이의 행복.json
# load file:	SOUR001869&&& 나의 어머니.json
# load file:	SOUR001870&&& 꺼레이.json
# load file:	SOUR001871&&& 땡볕.json
# load file:	SOUR001872&&& 논개(論개).json
# load file:	SOUR001873&&& 사벽송 (사벽송).json
# load file:	SOUR001876&&& 육사시집(육사시집) (시집).json
# load file:	SOUR001877&&& 봄은 고양이로다.json
# load file:	SOUR001878&&& 청천(청천)의 유방(유방).json
# load file:	SOUR001879&&& 하일소경 (하일소경).json
# load file:	SOUR001944&&& 백두산 근참기 (백두산 근참기).json
# load file:	SOUR002010&&& 모란이 피기까지는.json
# load file:	SOUR002012&&& 밤 기차에 그대를 보내고.json
# load file:	SOUR002014&&& 향수.json
# load file:	SOUR002015&&& 백록담(백록담).json
# load file:	SOUR002016&&& 이른봄 아침.json
# load file:	SOUR002017&&& 바다 1.json
# load file:	SOUR002018&&& 바다 2.json
# load file:	SOUR002019&&& 피리.json
# load file:	SOUR002020&&& 호수 1.json
# load file:	SOUR002021&&& 사슴.json
# load file:	SOUR002022&&& 남사당.json
# load file:	SOUR002023&&& 명문.json
# load file:	SOUR002024&&& 명화 리디아.json
# load file:	SOUR002025&&& 눈을 겨우 뜰 때.json
# load file:	SOUR002026&&& 어즈러움.json
# load file:	SOUR002027&&& 피고.json
# load file:	SOUR002028&&& 딸의 업을 이으려.json
# load file:	SOUR002029&&& 님의 부르심을 받들고서.json
# load file:	SOUR002030&&& 바다.json
# load file:	SOUR002031&&& 제1과 제1장.json
# load file:	SOUR002032&&& 흙의 노예(노례).json
# load file:	SOUR002033&&& 해 저문 나라에.json
# load file:	SOUR002034&&& 시악시 마음은.json
# load file:	SOUR002035&&& 청산백운 (청산백운).json
# load file:	SOUR002084&&& 이름 없는 여인이 되어.json
# load file:	SOUR002085&&& 푸른 오월.json
# load file:	SOUR002089&&& 적도 (적도).json
# load file:	SOUR002090&&& 선화공주 (선화공주).json
# load file:	SOUR002109&&& 심청.json
# load file:	SOUR002111&&& 안해.json
# load file:	SOUR002112&&& 십칠원 오십전 (십칠원오십전).json
# load file:	SOUR002115&&& 총각과 맹꽁이.json
# load file:	SOUR002116&&& 노다지.json
# load file:	SOUR002117&&& 금.json
# load file:	SOUR002118&&& 슬픈 이야기.json
# load file:	SOUR002175&&& 월광(월광)으로 짠 병실(병실).json
# load file:	SOUR002176&&& 춘향 (춘향).json
# load file:	SOUR002204&&& 미스터 방.json
# load file:	SOUR002249&&& 자모사 (자모사).json
# load file:	SOUR002250&&& 조춘 (조춘).json
# load file:	SOUR002251&&& 근화사(근화사) 삼첩(삼첩).json
# load file:	SOUR002252&&& 매화사(매화사) 삼첩(삼첩).json
# load file:	SOUR002253&&& 국화사(국화사) 삼첩(삼첩).json
# load file:	SOUR002254&&& 비로봉 (비로봉).json
# load file:	SOUR002271&&& 눈이 내리느니.json
# load file:	SOUR002272&&& 홍염 (홍염).json
# load file:	SOUR002273&&& 탈출기 (탈출기).json
# load file:	SOUR002274&&& 박돌(박돌)의 죽음.json
# load file:	SOUR002275&&& 기아(기아)와 살육(살륙).json
# load file:	SOUR002276&&& 고국.json
# load file:	SOUR002277&&& 십삼원 (습삼원).json
# load file:	SOUR002314&&& 서사록 (서차록).json
# load file:	SOUR002374&&& 영랑시집 (영랑시집) (시집).json
# load file:	SOUR002400&&& 곡 백범선생 (곡 백범선생).json
# load file:	SOUR002401&&& 파인(파인) 김동환(금동환) 님에게.json
# load file:	SOUR002405&&& 고도 순례 - 경주.json
# load file:	SOUR002406&&& 조선은 메나리 나라.json
# load file:	SOUR002407&&& 간도를 등지면서, 간도야 잘 있거라.json
# load file:	SOUR002408&&& 두만강 예찬.json
# load file:	SOUR002409&&& 기억에 남은 몽금포.json
# load file:	SOUR002410&&& 고(고) 이상(李상)의 추억.json
# load file:	SOUR002411&&& 오월의 산골작이.json
# load file:	SOUR002413&&& 애국고시조 (애국고시조).json
# load file:	SOUR002422&&& 기행 통군정 (기행 통군정).json
# load file:	SOUR002423&&& 기행 낙화암 (기행 낙화암).json
# load file:	SOUR002424&&& 해인사 기행 (해인사 기행).json
# load file:	SOUR002425&&& 기행 대동강, 초하의 패강을 예찬하며.json
# load file:	SOUR002426&&& 기행 남한산성 (기행 남한산성).json
# load file:	SOUR002427&&& 마지막날의 효석.json
# load file:	SOUR002428&&& 「쇼팡」치든인상.json
# load file:	SOUR002437&&& 고산자를 회함.json
# load file:	SOUR002442&&& 논개(논개)의 환생(환생).json
# load file:	SOUR002443&&& 망국인기(망국인기).json
# load file:	SOUR002444&&& 속 망국인기 (속 망국인기).json
# load file:	SOUR002445&&& 문단(문단) 30년의 자취.json
# load file:	SOUR002453&&& 문학(문학)이 부업(부업)이라던 박龍철형(박용철형).json
# load file:	SOUR002461&&& 인도의 토생원 별주부.json
# load file:	SOUR002466&&& 만세전 (만세전).json
# load file:	SOUR002467&&& 임종.json
# load file:	SOUR002468&&& 고향.json
# load file:	SOUR002469&&& 가마귀.json
# load file:	SOUR002470&&& 낙동강.json
# load file:	SOUR002471&&& 노령 근해 (露령근해).json
# load file:	SOUR002472&&& 농촌 사람들.json
# load file:	SOUR002473&&& 달밤.json
# load file:	SOUR002474&&& 도시와 유령(유령).json
# load file:	SOUR002475&&& 동해(동해).json
# load file:	SOUR002476&&& 복덕방.json
# load file:	SOUR002477&&& 분녀(분녀).json
# load file:	SOUR002478&&& 불.json
# load file:	SOUR002479&&& 수탉.json
# load file:	SOUR002480&&& 실화 (실화).json
# load file:	SOUR002481&&& 유치장에서 만난 사나이.json
# load file:	SOUR002482&&& 장미 병들다.json
# load file:	SOUR002483&&& 전아사 (전아사).json
# load file:	SOUR002484&&& 종생기 (종생기).json
# load file:	SOUR002485&&& 지주회시 (지주회시).json
# load file:	SOUR002486&&& 지형근 (지형근).json
# load file:	SOUR002487&&& 패강냉 (패강冷).json
# load file:	SOUR002488&&& 화수분.json
# load file:	SOUR002489&&& 효석과 나.json
# load file:	SOUR002490&&& 고리끼를 곡(곡)함.json
# load file:	SOUR002493&&& 조선문학(조선문학)의 변천.json
# load file:	SOUR002494&&& 李조시대(이조시대)의 문학.json
# load file:	SOUR002495&&& 『시문학(시문학)』 창간(창간)에 대(대)하야.json
# load file:	SOUR002496&&& 통속소설론 (통속소설론).json
# load file:	SOUR002497&&& 송영론 (송영론).json
# load file:	SOUR002498&&& 윤심덕(윤심덕) 정사(정사)에 관하여.json
# load file:	SOUR002499&&& 조선(조선) 가시(가시)의 연구.json
# load file:	SOUR002500&&& 춘원연구 (춘원연구).json
# load file:	SOUR002501&&& 허생전 (채만식).json
# load file:	SOUR002502&&& 허생전 (이광수).json
# load file:	SOUR002503&&& 춘원 이광수 씨를 말함.json
# load file:	SOUR002504&&& 가실 (가실).json
# load file:	SOUR002505&&& 도산 안창호 (도산 안창호).json
# load file:	SOUR002523&&& 희생화 (희생화).json
# load file:	SOUR002587&&& 꿈하늘.json
# load file:	SOUR002588&&& 인간문제 (인간문제).json
# load file:	SOUR002589&&& 어머니와 딸.json
# load file:	SOUR002590&&& 목마와 숙녀.json
# load file:	SOUR002591&&& 세월이 가면.json
# load file:	SOUR002621&&& 홍경래전 (홍경래전).json
# load file:	SOUR002626&&& 왕부(왕부)의 낙조(낙조).json
# load file:	SOUR002629&&& 동무를 위[위]하여.json
# load file:	SOUR002630&&& 호수(호수)의 여왕(여왕).json
# load file:	SOUR002631&&& 영길이의 설움.json
# load file:	SOUR002632&&& 마의태자 (마의태자).json
# load file:	SOUR002720&&& 님의 부르심을 받들고서.json
# load file:	SOUR002721&&& 님의 부르심을 받들고서.json
# load file:	SOUR002722&&& 님의 부르심을 받들고서.json
# load file:	SOUR002723&&& 님의 부르심을 받들고서.json
# load file:	SOUR002724&&& 님의 부르심을 받들고서.json
# load file:	SOUR002725&&& 님의 부르심을 받들고서.json
# load file:	SOUR002726&&& 반도학도특별지원병 제군에게.json
# load file:	SOUR002727&&& 유월의 언덕.json
# load file:	SOUR002728&&& 부인근로대.json
# load file:	SOUR002729&&& 송정오장(송정오장) 송가(송가).json
# load file:	SOUR002730&&& 어린 날개 - 히로오카 소년항공병에게.json
# load file:	SOUR002731&&& 지원병에게.json
# load file:	SOUR002732&&& 처음으로.json
# load file:	SOUR002733&&& 동방의 여인들.json
# load file:	SOUR002734&&& 싱가폴 함락.json
# load file:	SOUR002784&&& 노마만리 (노마만리).json
# load file:	SOUR002787&&& 호젓한 걸음.json
# load file:	SOUR002788&&& 백조시대(백조시대)에 남긴 여화(여화).json
# load file:	SOUR002846&&& 백팔번뇌 비평에 대하야.json
# load file:	SOUR002855&&& 정지용 시집 (정지용시집).json
# load file:	SOUR002856&&& 먼 후일(후일).json
# load file:	SOUR002857&&& 풀따기.json
# load file:	SOUR002858&&& 바다.json
# load file:	SOUR002859&&& 산(산) 위에.json
# load file:	SOUR002860&&& 옛 이야기.json
# load file:	SOUR002861&&& 님의 노래.json
# load file:	SOUR002862&&& 실제 (실제).json
# load file:	SOUR002863&&& 님의 말씀.json
# load file:	SOUR002864&&& 님에게.json
# load file:	SOUR002865&&& 마른 강(강) 두덕에서.json
# load file:	SOUR002866&&& 봄밤.json
# load file:	SOUR002867&&& 밤.json
# load file:	SOUR002868&&& 꿈꾼 그 옛날.json
# load file:	SOUR002869&&& 꿈으로 오는 한사람.json
# load file:	SOUR002870&&& 눈오는 저녁.json
# load file:	SOUR002871&&& 자주(자주) 구름.json
# load file:	SOUR002872&&& 두 사람.json
# load file:	SOUR002873&&& 닭소리.json
# load file:	SOUR002874&&& 못잊어.json
# load file:	SOUR002875&&& 예전엔 미처 몰랐어요.json
# load file:	SOUR002876&&& 자나께나 앉으나 서나.json
# load file:	SOUR002877&&& 해가 산마루에 저물어도.json
# load file:	SOUR002878&&& 꿈.json
# load file:	SOUR002879&&& 맘 켱기는 날.json
# load file:	SOUR002880&&& 하늘 끝.json
# load file:	SOUR002881&&& 개아미.json
# load file:	SOUR002882&&& 제비.json
# load file:	SOUR002883&&& 부헝새.json
# load file:	SOUR002884&&& 만리성 (만리성).json
# load file:	SOUR002885&&& 수아 (수아).json
# load file:	SOUR002886&&& 담배.json
# load file:	SOUR002887&&& 실제 (실제).json
# load file:	SOUR002888&&& 어버이.json
# load file:	SOUR002889&&& 부모 (부모).json
# load file:	SOUR002890&&& 후살이.json
# load file:	SOUR002891&&& 잊었던 맘.json
# load file:	SOUR002892&&& 봄비.json
# load file:	SOUR002893&&& 비단 안개.json
# load file:	SOUR002894&&& 기억 (기억).json
# load file:	SOUR002895&&& 애모 (애모).json
# load file:	SOUR002896&&& 몹쓸 꿈.json
# load file:	SOUR002897&&& 그를 꿈꾼 밤.json
# load file:	SOUR002898&&& 여자(여자)의 냄새.json
# load file:	SOUR002899&&& 분(분)얼골.json
# load file:	SOUR002900&&& 안해 몸.json
# load file:	SOUR002901&&& 서울 밤.json
# load file:	SOUR002902&&& 가을 아침.json
# load file:	SOUR002903&&& 가을 저녁에.json
# load file:	SOUR002904&&& 반달.json
# load file:	SOUR002905&&& 만나려는 심사(심사).json
# load file:	SOUR002906&&& 옛 낯.json
# load file:	SOUR002907&&& 깊이 믿던 심성(심성).json
# load file:	SOUR002908&&& 꿈.json
# load file:	SOUR002909&&& 님과 벗.json
# load file:	SOUR002910&&& 지연 (지연).json
# load file:	SOUR002911&&& 오시는 눈.json
# load file:	SOUR002912&&& 서름의 덩이.json
# load file:	SOUR002913&&& 낙천 (樂천).json
# load file:	SOUR002914&&& 바람과 봄.json
# load file:	SOUR002915&&& 눈.json
# load file:	SOUR002916&&& 깊고 깊은 언약.json
# load file:	SOUR002917&&& 붉은 조수(조수).json
# load file:	SOUR002918&&& 남의 나라 땅.json
# load file:	SOUR002919&&& 천리만리 (천리만리).json
# load file:	SOUR002920&&& 생(생)과 사(사).json
# load file:	SOUR002921&&& 어인 (어인).json
# load file:	SOUR002922&&& 귀뚜라미.json
# load file:	SOUR002923&&& 월색(월색).json
# load file:	SOUR002924&&& 불운(불운)에 우는 그대여.json
# load file:	SOUR002925&&& 바다가 변(변)하야 뽕나무밭 된다고.json
# load file:	SOUR002926&&& 황촉(황촉)불.json
# load file:	SOUR002927&&& 맘에 있는 말이라고 다 할까 보냐.json
# load file:	SOUR002928&&& 훗 길.json
# load file:	SOUR002929&&& 부부(부부).json
# load file:	SOUR002930&&& 나의 집.json
# load file:	SOUR002931&&& 새벽.json
# load file:	SOUR002932&&& 구름.json
# load file:	SOUR002933&&& 여름의 달밤.json
# load file:	SOUR002934&&& 오는 봄.json
# load file:	SOUR002935&&& 물마름.json
# load file:	SOUR002936&&& 우리집.json
# load file:	SOUR002937&&& 들놀이.json
# load file:	SOUR002938&&& 바리운 몸.json
# load file:	SOUR002939&&& 엄숙.json
# load file:	SOUR002940&&& 바라건대는 우리에게 보섭대일 땅이 있었더라면.json
# load file:	SOUR002941&&& 밭 고랑 우에서.json
# load file:	SOUR002942&&& 저녁 때.json
# load file:	SOUR002943&&& 합장(합장).json
# load file:	SOUR002944&&& 묵념(묵념).json
# load file:	SOUR002945&&& 열락(列樂).json
# load file:	SOUR002946&&& 무덤.json
# load file:	SOUR002947&&& 비난수하는 마음.json
# load file:	SOUR002948&&& 찬 저녁.json
# load file:	SOUR002949&&& 초혼(초혼).json
# load file:	SOUR002950&&& 여수(여수) 1.json
# load file:	SOUR002951&&& 여수(여수) 2.json
# load file:	SOUR002952&&& 개여울의 노래.json
# load file:	SOUR002953&&& 길.json
# load file:	SOUR002954&&& 개여울.json
# load file:	SOUR002955&&& 가는 길.json
# load file:	SOUR002956&&& 왕십리(왕십리).json
# load file:	SOUR002957&&& 원앙침(원앙침).json
# load file:	SOUR002958&&& 무심(무심).json
# load file:	SOUR002959&&& 산(산).json
# load file:	SOUR002960&&& 진달래꽃.json
# load file:	SOUR002961&&& 삭주구성(삭주구성).json
# load file:	SOUR002962&&& 널.json
# load file:	SOUR002963&&& 춘향(춘향)과 이도령(李도령).json
# load file:	SOUR002964&&& 접동새.json
# load file:	SOUR002965&&& 집 생각.json
# load file:	SOUR002966&&& 산유화(산유화).json
# load file:	SOUR002967&&& 꽃 촉(촉)불 켜는 밤.json
# load file:	SOUR002968&&& 부귀공명(부귀공명).json
# load file:	SOUR002969&&& 추회(추회).json
# load file:	SOUR002970&&& 무신(무신).json
# load file:	SOUR002971&&& 꿈길.json
# load file:	SOUR002972&&& 사노라면 사람은 죽는것을.json
# load file:	SOUR002973&&& 하다못해 죽어달래가 옳나.json
# load file:	SOUR002974&&& 희망(희망).json
# load file:	SOUR002975&&& 전망(전망).json
# load file:	SOUR002976&&& 나는 세상 모르고 살았노라.json
# load file:	SOUR002977&&& 금(금)잔디.json
# load file:	SOUR002978&&& 강촌(강촌).json
# load file:	SOUR002979&&& 첫치마.json
# load file:	SOUR002980&&& 달맞이.json
# load file:	SOUR002981&&& 엄마야 누나야.json
# load file:	SOUR002982&&& 닭은 꼬꾸요.json
# load file:	SOUR002983&&& 고적(고적)한 날.json
# load file:	SOUR002984&&& 장별리(장별리).json
# load file:	SOUR002985&&& 팔베개 노래.json
# load file:	SOUR002986&&& 차안서선생삼수갑산운(차안서선생삼수갑산운).json
# load file:	SOUR002987&&& 제이, 앰, 에스.json
# load file:	SOUR002988&&& 끝없는 강물이 흐르네.json
# load file:	SOUR002989&&& 돌담에 속삭이는 햇발.json
# load file:	SOUR002990&&& 언덕에 바로 누워.json
# load file:	SOUR002991&&& 뉘 눈결에 쏘이었소.json
# load file:	SOUR002992&&& 오매 단풍 들것네.json
# load file:	SOUR002993&&& 함박눈.json
# load file:	SOUR002994&&& 눈물에 실려 가면.json
# load file:	SOUR002995&&& 쓸쓸한 뫼 앞에.json
# load file:	SOUR002996&&& 꿈밭에 봄 마음.json
# load file:	SOUR002997&&& 님 두시고 가는 길.json
# load file:	SOUR002998&&& 허리띠 매는 시악시.json
# load file:	SOUR002999&&& 풀 위에 맺어지는 이슬.json
# load file:	SOUR003000&&& 좁은 길가에 무덤.json
# load file:	SOUR003001&&& 밤사람 그립고야.json
# load file:	SOUR003002&&& 숲 향기 숨길.json
# load file:	SOUR003003&&& 저녁때 외로운 마음.json
# load file:	SOUR003004&&& 무너진 성터.json
# load file:	SOUR003005&&& 산골 시악시.json
# load file:	SOUR003006&&& 그 색시 서럽다.json
# load file:	SOUR003007&&& 바람에 나부끼는.json
# load file:	SOUR003008&&& 뻘은 가슴을.json
# load file:	SOUR003009&&& 다정히도 불어오는 바람.json
# load file:	SOUR003010&&& 떠 날아가는 마음의.json
# load file:	SOUR003011&&& 애닯은 입김.json
# load file:	SOUR003012&&& 뵈지도 않는 입김.json
# load file:	SOUR003013&&& 사랑은 깊으기 푸른 하늘.json
# load file:	SOUR003014&&& 미움이란 말 속에.json
# load file:	SOUR003015&&& 눈물 속 빛나는 보람.json
# load file:	SOUR003016&&& 외론 할미꽃.json
# load file:	SOUR003017&&& 설운 소리.json
# load file:	SOUR003018&&& 구름 속 종달.json
# load file:	SOUR003019&&& 향내 없다고.json
# load file:	SOUR003020&&& 언덕에 누워.json
# load file:	SOUR003021&&& 푸른 향물.json
# load file:	SOUR003022&&& 빠른 철로에 조는 손님.json
# load file:	SOUR003023&&& 생각하면 부끄러운.json
# load file:	SOUR003024&&& 온몸을 감도는.json
# load file:	SOUR003025&&& 제야(제야).json
# load file:	SOUR003026&&& 내 옛날 온 꿈이.json
# load file:	SOUR003027&&& 그대는 호령도 하실 만하다.json
# load file:	SOUR003028&&& 아파 누워.json
# load file:	SOUR003029&&& 가늘한 내음.json
# load file:	SOUR003030&&& 내 마음을 아실 이.json
# load file:	SOUR003031&&& 시냇물 소리.json
# load file:	SOUR003032&&& 불지암서정(불지암서정).json
# load file:	SOUR003033&&& 물 보면 흐르고.json
# load file:	SOUR003034&&& 강선대(강선대) 돌바늘 끝에.json
# load file:	SOUR003035&&& 사개 틀린 고풍의 툇마루에.json
# load file:	SOUR003036&&& 마당 앞 맑은 새암을.json
# load file:	SOUR003037&&& 황홀한 달빛.json
# load file:	SOUR003038&&& 두견(두견).json
# load file:	SOUR003039&&& 청명.json
# load file:	SOUR003040&&& 서시(서시).json
# load file:	SOUR003041&&& 자화상.json
# load file:	SOUR003042&&& 소년.json
# load file:	SOUR003043&&& 눈 오는 지도.json
# load file:	SOUR003044&&& 돌아와 보는 밤.json
# load file:	SOUR003045&&& 병원.json
# load file:	SOUR003046&&& 새로운 길.json
# load file:	SOUR003047&&& 간판 없는 거리.json
# load file:	SOUR003048&&& 태초의 아침.json
# load file:	SOUR003049&&& 또 태초의 아침.json
# load file:	SOUR003050&&& 새벽이 올 때까지.json
# load file:	SOUR003051&&& 무서운 시간.json
# load file:	SOUR003052&&& 십자가(십자가).json
# load file:	SOUR003053&&& 바람이 불어.json
# load file:	SOUR003054&&& 슬픈 족속.json
# load file:	SOUR003055&&& 눈 감고 간다.json
# load file:	SOUR003056&&& 또 다른 고향(고향).json
# load file:	SOUR003057&&& 길.json
# load file:	SOUR003058&&& 별 헤는 밤.json
# load file:	SOUR003059&&& 호수 2.json
# load file:	SOUR003060&&& 백록담(백록담) (시집).json
# load file:	SOUR003061&&& 꿈의 노래.json
# load file:	SOUR003062&&& 잃어진 봄.json
# load file:	SOUR003063&&& 피리.json
# load file:	SOUR003064&&& 내 설움.json
# load file:	SOUR003065&&& 풀밭 위.json
# load file:	SOUR003066&&& 바다 저편.json
# load file:	SOUR003067&&& 달과 함께.json
# load file:	SOUR003068&&& 배.json
# load file:	SOUR003069&&& 갈매기.json
# load file:	SOUR003070&&& 잃어지는 기억.json
# load file:	SOUR003071&&& 눈 1.json
# load file:	SOUR003072&&& 가을 1.json
# load file:	SOUR003073&&& 임금과 복숭아.json
# load file:	SOUR003074&&& 안동현의 밤.json
# load file:	SOUR003075&&& 눈 2.json
# load file:	SOUR003076&&& 별 낚기.json
# load file:	SOUR003077&&& 십일월의 저녁.json
# load file:	SOUR003078&&& 가을 2.json
# load file:	SOUR003079&&& 실제(실제) 1.json
# load file:	SOUR003080&&& 고적.json
# load file:	SOUR003081&&& 사계의 노래.json
# load file:	SOUR003082&&& 표박(표박).json
# load file:	SOUR003083&&& 하품론(논).json
# load file:	SOUR003084&&& 입.json
# load file:	SOUR003085&&& 아침잠.json
# load file:	SOUR003086&&& 붉은 키쓰.json
# load file:	SOUR003087&&& 탄식(탄식).json
# load file:	SOUR003088&&& 새빨간 핏빛의 진달래꽃이 질 때.json
# load file:	SOUR003089&&& 애닯기도 하여라.json
# load file:	SOUR003090&&& 화인(화인).json
# load file:	SOUR003091&&& 달.json
# load file:	SOUR003092&&& 황포(황포)의 바다.json
# load file:	SOUR003093&&& 실제(실제) 2.json
# load file:	SOUR003094&&& 참살구.json
# load file:	SOUR003095&&& 사향(사향).json
# load file:	SOUR003096&&& 꽃의 목숨.json
# load file:	SOUR003097&&& 이슬.json
# load file:	SOUR003098&&& 봉선화(봉선화).json
# load file:	SOUR003099&&& 초순(초순) 달.json
# load file:	SOUR003100&&& 눈물.json
# load file:	SOUR003101&&& 남겨진 향내.json
# load file:	SOUR003102&&& 가는 봄.json
# load file:	SOUR003103&&& 야자(야자)의 몸.json
# load file:	SOUR003104&&& 죽음.json
# load file:	SOUR003105&&& 언제 오셔요.json
# load file:	SOUR003106&&& 밤의 대동강가에서.json
# load file:	SOUR003107&&& 강가에서.json
# load file:	SOUR003108&&& 기억은 죽지도 않는가.json
# load file:	SOUR003109&&& 내 세상은 물이런가 구름이런가.json
# load file:	SOUR003110&&& 삼월에도 삼짇날.json
# load file:	SOUR003111&&& 기억(기억).json
# load file:	SOUR003112&&& 별후(별후).json
# load file:	SOUR003113&&& 가을 3.json
# load file:	SOUR003114&&& 설운 희극(희극).json
# load file:	SOUR003115&&& 기도(기도).json
# load file:	SOUR003116&&& 저락(저락)된 눈물.json
# load file:	SOUR003117&&& 비극(비극)의 서곡(서곡).json
# load file:	SOUR003118&&& 우정(우정).json
# load file:	SOUR003119&&& 탈춤.json
# load file:	SOUR003120&&& 실제(실제) 3.json
# load file:	SOUR003121&&& 사랑의 때.json
# load file:	SOUR003122&&& 때.json
# load file:	SOUR003123&&& 죽은 기억(기억).json
# load file:	SOUR003124&&& 낙엽(낙엽).json
# load file:	SOUR003125&&& 전원(전원)의 황혼(황혼).json
# load file:	SOUR003126&&& 봄은 와서.json
# load file:	SOUR003127&&& 유월의 낮잠.json
# load file:	SOUR003128&&& 북방(북방)의 따님.json
# load file:	SOUR003129&&& 유랑(유랑)의 노래.json
# load file:	SOUR003130&&& 난홈의 노래 (나눔의 노래).json
# load file:	SOUR003131&&& 망우(망우).json
# load file:	SOUR003132&&& 삼 년의 옛날.json
# load file:	SOUR003133&&& 무덤.json
# load file:	SOUR003134&&& 봄의 선녀(선녀).json
# load file:	SOUR003135&&& 악성(낙성).json
# load file:	SOUR003136&&& 나의 이상(이상).json
# load file:	SOUR003137&&& 상실(상실).json
# load file:	SOUR003138&&& 님의 침묵(침묵).json
# load file:	SOUR003139&&& 이별은 미(미)의 창조(창조).json
# load file:	SOUR003140&&& 알 수 없어요.json
# load file:	SOUR003141&&& 나는 잊고저.json
# load file:	SOUR003142&&& 가지 마셔요.json
# load file:	SOUR003143&&& 고적한 밤.json
# load file:	SOUR003144&&& 나의 길.json
# load file:	SOUR003145&&& 꿈 깨고서.json
# load file:	SOUR003146&&& 예술가(예술가).json
# load file:	SOUR003147&&& 이별.json
# load file:	SOUR003148&&& 길이 막혀.json
# load file:	SOUR003149&&& 자유정조(자유정조).json
# load file:	SOUR003150&&& 하나가 되어주셔요.json
# load file:	SOUR003151&&& 나룻배와 행인(행인).json
# load file:	SOUR003152&&& 차라리.json
# load file:	SOUR003153&&& 나의 노래.json
# load file:	SOUR003154&&& 당신이 아니더면.json
# load file:	SOUR003155&&& 잠 없는 꿈.json
# load file:	SOUR003156&&& 생명(생명).json
# load file:	SOUR003157&&& 사랑의 측량(측량).json
# load file:	SOUR003158&&& 진주(진주).json
# load file:	SOUR003159&&& 슬픔의 삼매(삼매).json
# load file:	SOUR003160&&& 의심하지 마셔요.json
# load file:	SOUR003161&&& 당신은.json
# load file:	SOUR003162&&& 행복(행복).json
# load file:	SOUR003163&&& 착인(착인).json
# load file:	SOUR003164&&& 밤은 고요하고.json
# load file:	SOUR003165&&& 비밀(비밀).json
# load file:	SOUR003166&&& 사랑의 존재(존재).json
# load file:	SOUR003167&&& 꿈과 근심.json
# load file:	SOUR003168&&& 포도주(포도주).json
# load file:	SOUR003169&&& 비방(비방).json
# load file:	SOUR003170&&& ？ (물음표).json
# load file:	SOUR003171&&& 님의 손길.json
# load file:	SOUR003172&&& 해당화(해당화).json
# load file:	SOUR003173&&& 당신을 보았습니다.json
# load file:	SOUR003174&&& 비.json
# load file:	SOUR003175&&& 복종(복종).json
# load file:	SOUR003176&&& 참아 주셔요.json
# load file:	SOUR003177&&& 어느것이 참이냐.json
# load file:	SOUR003178&&& 정천한해(정천한해).json
# load file:	SOUR003179&&& 첫 키스.json
# load file:	SOUR003180&&& 선사(선사)의 설법(설법).json
# load file:	SOUR003181&&& 그를 보내며.json
# load file:	SOUR003182&&& 금강산(금강산).json
# load file:	SOUR003183&&& 님의 얼굴.json
# load file:	SOUR003184&&& 심은 버들.json
# load file:	SOUR003185&&& 낙원(낙원)은 가시덤풀에서.json
# load file:	SOUR003186&&& 참말인가요.json
# load file:	SOUR003187&&& 꽃이 먼저 알아.json
# load file:	SOUR003188&&& 찬송(찬송).json
# load file:	SOUR003189&&& 논개(논개)의 애인(애인)이 되어서 그의 묘(묘)에.json
# load file:	SOUR003190&&& 후회(후회).json
# load file:	SOUR003191&&& 사랑하는 까닭.json
# load file:	SOUR003192&&& 당신의 편지.json
# load file:	SOUR003193&&& 거짓 이별.json
# load file:	SOUR003194&&& 꿈이라면.json
# load file:	SOUR003195&&& 달을 보며.json
# load file:	SOUR003196&&& 인과율(인과율).json
# load file:	SOUR003197&&& 잠꼬대.json
# load file:	SOUR003198&&& 계월향(계월향)에게.json
# load file:	SOUR003199&&& 만족(만족).json
# load file:	SOUR003200&&& 반비례(반비례).json
# load file:	SOUR003201&&& 눈물.json
# load file:	SOUR003202&&& 어디라도.json
# load file:	SOUR003203&&& 떠날 때의 님의 얼굴.json
# load file:	SOUR003204&&& 최초(최초)의 님.json
# load file:	SOUR003205&&& 두견새.json
# load file:	SOUR003206&&& 나의 꿈.json
# load file:	SOUR003207&&& 우는 때.json
# load file:	SOUR003208&&& 타골의 시(GARDENISTO)를 읽고.json
# load file:	SOUR003209&&& 수(수)의 비밀(비밀).json
# load file:	SOUR003210&&& 사랑의 불.json
# load file:	SOUR003211&&& 사랑을 사랑하여요.json
# load file:	SOUR003212&&& 버리지 아니하면.json
# load file:	SOUR003213&&& 당신 가신 때.json
# load file:	SOUR003214&&& 요술(요술).json
# load file:	SOUR003215&&& 당신의 마음.json
# load file:	SOUR003216&&& 여름밤이 길어요.json
# load file:	SOUR003217&&& 명상(명상).json
# load file:	SOUR003218&&& 칠석(칠석).json
# load file:	SOUR003219&&& 생(생)의 예술(예술).json
# load file:	SOUR003220&&& 꽃싸움.json
# load file:	SOUR003221&&& 거문고 탈 때.json
# load file:	SOUR003222&&& 오셔요.json
# load file:	SOUR003223&&& 쾌락(쾌락).json
# load file:	SOUR003224&&& 고대(고대).json
# load file:	SOUR003225&&& 사랑의 끝판.json
# load file:	SOUR003226&&& 황혼(황혼).json
# load file:	SOUR003227&&& 청포도(청포도).json
# load file:	SOUR003228&&& 노정기(노정기).json
# load file:	SOUR003229&&& 연보(연보).json
# load file:	SOUR003230&&& 절정(절정).json
# load file:	SOUR003231&&& 아편(아편).json
# load file:	SOUR003232&&& 나의 뮤즈.json
# load file:	SOUR003233&&& 교목(교목).json
# load file:	SOUR003234&&& 아미(아미).json
# load file:	SOUR003235&&& 자야곡(자야곡).json
# load file:	SOUR003236&&& 호수(호수).json
# load file:	SOUR003237&&& 소년에게.json
# load file:	SOUR003238&&& 강 건너간 노래.json
# load file:	SOUR003239&&& 파초(파초).json
# load file:	SOUR003240&&& 반묘(반묘).json
# load file:	SOUR003241&&& 독백(독백).json
# load file:	SOUR003242&&& 일식(일식).json
# load file:	SOUR003243&&& 해후(해후).json
# load file:	SOUR003244&&& 광야(광야).json
# load file:	SOUR003245&&& 꽃.json
# load file:	SOUR003246&&& 비로봉.json
# load file:	SOUR003247&&& 홍역(홍역).json
# load file:	SOUR003248&&& 비극.json
# load file:	SOUR003249&&& 시계를 죽임.json
# load file:	SOUR003250&&& 아침.json
# load file:	SOUR003251&&& 바람.json
# load file:	SOUR003252&&& 유리창(유리창) 1.json
# load file:	SOUR003253&&& 유리창(유리창) 2.json
# load file:	SOUR003254&&& 난초.json
# load file:	SOUR003255&&& 촉불과 손.json
# load file:	SOUR003256&&& 해협.json
# load file:	SOUR003257&&& 다시 해협.json
# load file:	SOUR003258&&& 지도.json
# load file:	SOUR003259&&& 귀로 (귀로).json
# load file:	SOUR003260&&& 오월 소식.json
# load file:	SOUR003261&&& 압천 (압천).json
# load file:	SOUR003262&&& 석류.json
# load file:	SOUR003263&&& 발열 (발열).json
# load file:	SOUR003264&&& 갑판 우.json
# load file:	SOUR003265&&& 태극선 (태극선).json
# load file:	SOUR003267&&& 카페 · 프란스.json
# load file:	SOUR003268&&& 슬픈 인상화 (인상화).json
# load file:	SOUR003269&&& 조약돌.json
# load file:	SOUR003270&&& 따알리아.json
# load file:	SOUR003271&&& 홍춘 (홍춘).json
# load file:	SOUR003272&&& 저녁햇살.json
# load file:	SOUR003273&&& 뻣나무 열매.json
# load file:	SOUR003274&&& 엽서에 쓴 글.json
# load file:	SOUR003275&&& 선취 (선취).json
# load file:	SOUR003276&&& 봄.json
# load file:	SOUR003277&&& 슬픈 기차(기차).json
# load file:	SOUR003278&&& 황마차 (황마차).json
# load file:	SOUR003279&&& 새빨간 기관차.json
# load file:	SOUR003280&&& 밤.json
# load file:	SOUR003281&&& 호면.json
# load file:	SOUR003282&&& 겨울.json
# load file:	SOUR003283&&& 달.json
# load file:	SOUR003284&&& 절정 (절정).json
# load file:	SOUR003285&&& 풍랑몽 1.json
# load file:	SOUR003286&&& 풍랑몽 2.json
# load file:	SOUR003287&&& 말 1.json
# load file:	SOUR003288&&& 말 2.json
# load file:	SOUR003289&&& 바다 1.json
# load file:	SOUR003290&&& 바다 2.json
# load file:	SOUR003291&&& 바다 3.json
# load file:	SOUR003292&&& 바다 4.json
# load file:	SOUR003293&&& 바다 5.json
# load file:	SOUR003294&&& 갈매기.json
# load file:	SOUR003295&&& 해바라기 씨.json
# load file:	SOUR003296&&& 지는 해.json
# load file:	SOUR003297&&& 띠.json
# load file:	SOUR003298&&& 산너머 저쪽.json
# load file:	SOUR003299&&& 홍시.json
# load file:	SOUR003300&&& 무서운 시계.json
# load file:	SOUR003301&&& 삼월 삼질 날.json
# load file:	SOUR003302&&& 딸레.json
# load file:	SOUR003303&&& 산소.json
# load file:	SOUR003304&&& 종달새.json
# load file:	SOUR003305&&& 병.json
# load file:	SOUR003306&&& 할아버지.json
# load file:	SOUR003307&&& 말.json
# load file:	SOUR003308&&& 산에서 온 새.json
# load file:	SOUR003309&&& 바람.json
# load file:	SOUR003310&&& 별똥.json
# load file:	SOUR003311&&& 기차.json
# load file:	SOUR003312&&& 고향.json
# load file:	SOUR003313&&& 산엣 색시 들녘 사내.json
# load file:	SOUR003314&&& 내 맘에 맞는 이.json
# load file:	SOUR003315&&& 무어래요.json
# load file:	SOUR003316&&& 숨ㅅ기 내기.json
# load file:	SOUR003317&&& 비듥이.json
# load file:	SOUR003318&&& 불사조.json
# load file:	SOUR003319&&& 나무.json
# load file:	SOUR003320&&& 은혜.json
# load file:	SOUR003321&&& 별.json
# load file:	SOUR003322&&& 임종.json
# load file:	SOUR003323&&& 갈릴레아 바다.json
# load file:	SOUR003324&&& 그의 반.json
# load file:	SOUR003325&&& 다른 한울.json
# load file:	SOUR003326&&& 또 하나 다른 태양.json
# load file:	SOUR003327&&& 소묘(소묘) 1.json
# load file:	SOUR003328&&& 소묘(소묘) 2.json
# load file:	SOUR003329&&& 소묘(소묘) 3.json
# load file:	SOUR003330&&& 소묘(소묘) 4 (밤).json
# load file:	SOUR003331&&& 소묘(소묘) 5 (람프).json
# load file:	SOUR003332&&& 장수산(장수산) 1.json
# load file:	SOUR003333&&& 장수산(장수산) 2.json
# load file:	SOUR003334&&& 비로봉(비로봉).json
# load file:	SOUR003335&&& 구성동(구성동).json
# load file:	SOUR003336&&& 옥류동(옥류동).json
# load file:	SOUR003337&&& 조찬(조찬).json
# load file:	SOUR003338&&& 비.json
# load file:	SOUR003339&&& 인동차(인동다).json
# load file:	SOUR003340&&& 붉은 손.json
# load file:	SOUR003341&&& 꽃과 벗.json
# load file:	SOUR003342&&& 폭포.json
# load file:	SOUR003343&&& 온정(온정).json
# load file:	SOUR003344&&& 삽사리.json
# load file:	SOUR003345&&& 나비.json
# load file:	SOUR003346&&& 진달래.json
# load file:	SOUR003347&&& 호랑나비.json
# load file:	SOUR003348&&& 예장(예장).json
# load file:	SOUR003349&&& 선취(선취).json
# load file:	SOUR003350&&& 유선애상(유선애상).json
# load file:	SOUR003351&&& 춘설(춘설).json
# load file:	SOUR003352&&& 소곡(소곡).json
# load file:	SOUR003353&&& 파라솔.json
# load file:	SOUR003354&&& 별.json
# load file:	SOUR003355&&& 슬픈 우상(우상).json
# load file:	SOUR003356&&& 이목구비(이목구비).json
# load file:	SOUR003357&&& 예양(예양).json
# load file:	SOUR003358&&& 비.json
# load file:	SOUR003359&&& 아스팔트.json
# load file:	SOUR003360&&& 노인(노인)과 꽃.json
# load file:	SOUR003361&&& 꾀꼬리와 국화(국화).json
# load file:	SOUR003362&&& 비둘기.json
# load file:	SOUR003363&&& 육체(육체).json
# load file:	SOUR003364&&& 매화 칠장 (매화칠장).json
# load file:	SOUR003365&&& 만폭동(만폭동).json
# load file:	SOUR003366&&& 매월당석각(매월당석각).json
# load file:	SOUR003367&&& 마하연암(마가연암).json
# load file:	SOUR003368&&& 표훈사(표훈사).json
# load file:	SOUR003369&&& 정양사(정양사).json
# load file:	SOUR003370&&& 소광암(소광암).json
# load file:	SOUR003371&&& 칠보암(칠보암).json
# load file:	SOUR003372&&& 마의태자릉(마의태자陵).json
# load file:	SOUR003373&&& 구룡연(구룡연).json
# load file:	SOUR003374&&& 비봉폭(비봉폭).json
# load file:	SOUR003375&&& 옥류동(옥류동).json
# load file:	SOUR003376&&& 문호암 애사(문호암애사).json
# load file:	SOUR003377&&& 박연행(박연행).json
# load file:	SOUR003378&&& 백마강(백마강) 뱃 속에서.json
# load file:	SOUR003379&&& 십이애(십이애).json
# load file:	SOUR003380&&& 여수(麗수)서 목포(목포)까지.json
# load file:	SOUR003381&&& 여수 옥천사(여수옥천사).json
# load file:	SOUR003382&&& 유모 강씨의 상행(상행)을 보내면서.json
# load file:	SOUR003383&&& 이화사(梨화사) 삼첩(삼첩).json
# load file:	SOUR003384&&& 첫 정.json
# load file:	SOUR003385&&& 궁겨워.json
# load file:	SOUR003386&&& 안겨서.json
# load file:	SOUR003387&&& 떠나서.json
# load file:	SOUR003388&&& 어쩔까.json
# load file:	SOUR003813&&& 서울로 간다는 소.json
# load file:	SOUR003814&&& 깨트려지는 홍등.json
# load file:	SOUR003815&&& 경희(경희).json
# load file:	SOUR003816&&& 공장신문 (공장신문).json
# load file:	SOUR003817&&& 역로(歷로).json
# load file:	SOUR003818&&& 공상구락부.json
# load file:	SOUR003819&&& 할머니의 죽음.json
# load file:	SOUR003820&&& 별을 안거든 울지나 말걸.json
# load file:	SOUR003821&&& 처를 때리고.json
# load file:	SOUR003822&&& 큰물 진 뒤.json
# load file:	SOUR003823&&& 맹순사 (맹순사).json
# load file:	SOUR003824&&& 그립은 흘긴 눈.json
# load file:	SOUR003825&&& 풀잎.json
# load file:	SOUR003826&&& 토혈(토혈).json
# load file:	SOUR003827&&& 흙의 세례.json
# load file:	SOUR003828&&& 전차 차장의 일기 몇 절.json
# load file:	SOUR003829&&& 사립정신병원장(사립정신병원장).json
# load file:	SOUR004297&&& 거사가(거사가).json
# load file:	SOUR004298&&& 장부가(장부가).json
# load file:	SOUR004299&&& 안중근 의사의 거사 소식을 듣고 (문의병장안중근보국수사).json
# load file:	SOUR004305&&& 통곡(통곡).json
# load file:	SOUR004306&&& 역천(역천).json
# load file:	SOUR004307&&& 조선병(조선병).json
# load file:	SOUR004308&&& 시인에게.json
# load file:	SOUR004309&&& 폭풍우를 기다리는 마음.json
# load file:	SOUR004310&&& 나무리벌 노래.json
# load file:	SOUR004311&&& 옷과 밥과 자유.json
# load file:	SOUR004312&&& 겨울.json
# load file:	SOUR004313&&& 봄바람.json
# load file:	SOUR004314&&& 무제(무제).json
# load file:	SOUR004315&&& 님이시여.json
# load file:	SOUR004316&&& 봄의 서곡(서곡).json
# load file:	SOUR004317&&& 나의 강산이여.json
# load file:	SOUR004318&&& 그날이 오면.json
# load file:	SOUR004319&&& 통곡 속에서.json
# load file:	SOUR004320&&& 너에게 무엇을 주랴.json
# load file:	SOUR004321&&& 오오 조선의 남아여.json
# load file:	SOUR004322&&& 독(독)을 차고.json
# load file:	SOUR004323&&& 망각(망각).json
# load file:	SOUR004324&&& 천리(천리)를 올라온다.json
# load file:	SOUR004325&&& 고향.json
# load file:	SOUR004326&&& 한 조각 하날.json
# load file:	SOUR004327&&& 기원(기원).json
# load file:	SOUR004328&&& 한 개의 별을 노래하자.json
# load file:	SOUR004329&&& 쉽게 씌여진 시(시).json
# load file:	SOUR004330&&& 참회록(참회록).json
# load file:	SOUR004331&&& 간(간).json
# load file:	SOUR004332&&& 황공의 최후.json
# load file:	SOUR004333&&& 오리온과 능금.json
# load file:	SOUR004334&&& 대동강은 속삭인다.json
# load file:	SOUR004335&&& 소망(소망).json
# load file:	SOUR004336&&& 도정(도정).json
# load file:	SOUR004338&&& 별.json
# load file:	SOUR004339&&& O형의 인간.json
# load file:	SOUR004340&&& 산협(산협).json
# load file:	SOUR004341&&& 어촌.json
# load file:	SOUR004342&&& 모자(모자).json
# load file:	SOUR004343&&& 현숙(현숙).json
# load file:	SOUR004344&&& 정조(정조)와 약가(약가).json
# load file:	SOUR004345&&& 바람은 그냥 불고.json
# load file:	SOUR004346&&& J의사의 고백.json
# load file:	SOUR004347&&& B녀의 소묘(소묘).json
# load file:	SOUR004348&&& 성찬(성찬).json
# load file:	SOUR004349&&& 길.json
# load file:	SOUR004350&&& 정희.json
# load file:	SOUR004351&&& 신문지와 철창.json
# load file:	SOUR004352&&& 정조(정조).json
# load file:	SOUR004353&&& 팔려간 몸.json
# load file:	SOUR004354&&& 까막잡기.json
# load file:	SOUR004355&&& 무능자의 아내.json
# load file:	SOUR004356&&& 새 거지.json
# load file:	SOUR004357&&& 쑥국새.json
# load file:	SOUR004358&&& 야앵(야앵).json
# load file:	SOUR004359&&& 해바라기.json
# load file:	SOUR004360&&& 이효석씨저 (李효석씨저) 해바라기.json
# load file:	SOUR004361&&& 연애삽화(戀애삽화).json
# load file:	SOUR004362&&& 유모(유모).json
# load file:	SOUR004363&&& 보석반지(보석반지).json
# load file:	SOUR004364&&& 가상의 불량소녀.json
# load file:	SOUR004365&&& 약령기(약령기).json
# load file:	SOUR004366&&& 소녀.json
# load file:	SOUR004367&&& 파금(파금).json
# load file:	SOUR004368&&& 청춘도(청춘도).json
# load file:	SOUR004369&&& 자기를 찾기 전.json
# load file:	SOUR004370&&& 굉장 씨(굉장씨).json
# load file:	SOUR004371&&& 그믐날.json
# load file:	SOUR004372&&& 두 순정(순정).json
# load file:	SOUR004373&&& 발(염).json
# load file:	SOUR004374&&& 백금.json
# load file:	SOUR004375&&& 행랑 자식.json
# load file:	SOUR004376&&& 미치광이.json
# load file:	SOUR004377&&& 반역자.json
# load file:	SOUR004378&&& 번뇌의 밤.json
# load file:	SOUR004379&&& 북국점경(북국점경).json
# load file:	SOUR004380&&& 불효자식.json
# load file:	SOUR004381&&& 산남(산남).json
# load file:	SOUR004382&&& 악부자.json
# load file:	SOUR004383&&& 준광인전(준광인전).json
# load file:	SOUR004384&&& 춘성(춘성).json
# load file:	SOUR004385&&& 목가(목가).json
# load file:	SOUR004386&&& 무서운 인상(인상).json
# load file:	SOUR004387&&& 저항 문학(저항문학)의 저항적 기술.json
# load file:	SOUR004388&&& 무엇을 어떻게 쓸 것인가？.json
# load file:	SOUR004389&&& 세태소설론(세태소설론).json
# load file:	SOUR004390&&& 번뇌(번뇌).json
# load file:	SOUR004391&&& 벽화(벽화).json
# load file:	SOUR004392&&& 생명(생명)의 유희(유희).json
# load file:	SOUR004393&&& 소라.json
# load file:	SOUR004394&&& 어여쁜 악마.json
# load file:	SOUR004395&&& 채색교.json
# load file:	SOUR004396&&& 피묻은 편지 몇 쪽.json
# load file:	SOUR004397&&& 화환.json
# load file:	SOUR004398&&& 가을.json
# load file:	SOUR004399&&& 동대문(동대문).json
# load file:	SOUR004400&&& 부부(부부).json
# load file:	SOUR004401&&& 소독부.json
# load file:	SOUR004402&&& 용동댁의 경우.json
# load file:	SOUR004403&&& 이리.json
# load file:	SOUR004404&&& 일요일.json
# load file:	SOUR004405&&& 장화(장화).json
# load file:	SOUR004406&&& 주춧돌.json
# load file:	SOUR004407&&& 반점(반점).json
# load file:	SOUR004408&&& 버릇.json
# load file:	SOUR004409&&& 산길.json
# load file:	SOUR004410&&& 아부용(아부용).json
# load file:	SOUR004411&&& 오디.json
# load file:	SOUR004412&&& 망령의 난무.json
# load file:	SOUR004413&&& 오리알.json
# load file:	SOUR004414&&& 일여인.json
# load file:	SOUR004415&&& 우심(우심).json
# load file:	SOUR004416&&& 누가 망하나.json
# load file:	SOUR004417&&& 장벽(장벽).json
# load file:	SOUR004418&&& 얼어죽은 모나리자.json
# load file:	SOUR004499&&& 천일야화(천일야화).json
# load file:	SOUR004504&&& 대하(대하).json
# load file:	SOUR004505&&& 맥(맥).json
# load file:	SOUR004506&&& 채만식 저 탁류의 매력 - 연재소설의 새 경지.json
# load file:	SOUR004507&&& 민족 대서사시의 영웅적 주인공 박헌영 선생.json
# load file:	SOUR004508&&& 채만식 [탁류]와 안희남의 단편 - 세태 · 풍속 묘사 기타.json
# load file:	SOUR004509&&& 평양 잡기첩(잡기첩) - 뒷골목.json
# load file:	SOUR004510&&& 무전여행.json
# load file:	SOUR004511&&& 처용고(처용고).json
# load file:	SOUR004512&&& 고구려(고구려)의 문학.json
# load file:	SOUR004513&&& 조선문학(조선문학)의 기원.json
# load file:	SOUR004521&&& 새로운 창작방법에 관하여.json
# load file:	SOUR004544&&& 이광수류의 문학을 매장하라.json
# load file:	SOUR004545&&& 토끼의 간(간).json
# load file:	SOUR004546&&& 내가 본 시인(시인) - 주요한(주요한) 군(군)을 논(論)함.json
# load file:	SOUR004547&&& 내가 본 시인(시인) - 김소월(金소월) 군(군)을 논(論)함.json
# load file:	SOUR004549&&& 계유(계유)·병자(병자)·정축(정축) - 사육신(사六신)과 남추강(남추강).json
# load file:	SOUR004550&&& 기묘사화(기묘사화) 재검토(재검토).json
# load file:	SOUR004551&&& 장사(장사)의 한(한).json
# load file:	SOUR004552&&& 민족(민족)의 죄인(죄인).json
# load file:	SOUR004553&&& 국치일의 회고.json
# load file:	SOUR004554&&& 시대와 문학의 정신.json
# load file:	SOUR004555&&& 창작과정에 대한 감상.json
# load file:	SOUR004556&&& 이효석 저 화분의 성 모랄.json
# load file:	SOUR004557&&& 건전(건전)한 사실주의사실주의)의 길.json
# load file:	SOUR004558&&& 남행기(남행기).json
# load file:	SOUR004559&&& 유정(유정)과 나.json
# load file:	SOUR004560&&& 소설을 잘 씁시다.json
# load file:	SOUR004561&&& 문예비평가론(문예비평가론).json
# load file:	SOUR004562&&& 문예비평가론 - 문예비평과 이데올로기.json
# load file:	SOUR004563&&& 비평(비평)에 대하여.json
# load file:	SOUR004564&&& 탁류(탁류)의 계봉(계봉).json
# load file:	SOUR004565&&& 소설가(소설가)는 이렇게 생각한다.json
# load file:	SOUR004567&&& 강원도 동해안의 바다와 산과 들.json
# load file:	SOUR004568&&& 살인작가.json
# load file:	SOUR004569&&& 현대 조선소설(현대 조선소설)의 이념(理념).json
# load file:	SOUR004570&&& 스승 무용기(무용기).json
# load file:	SOUR004571&&& 신문소설(신문소설)은 어떻게 써야 하나.json
# load file:	SOUR004572&&& 낭만주의론.json
# load file:	SOUR004573&&& 임화(林화)에 관하여.json
# load file:	SOUR004574&&& 몽상의 순결성.json
# load file:	SOUR004575&&& 아메리칸 리얼리즘의 교훈.json
# load file:	SOUR004576&&& 인간 수업 독후감.json
# load file:	SOUR004577&&& 작금(작금)의 신문소설.json
# load file:	SOUR004578&&& 자작안내(자작안내).json
# load file:	SOUR004579&&& 자작안내(자작안내).json
# load file:	SOUR004580&&& 본격소설론(본격소설론).json
# load file:	SOUR004581&&& 예술적(예술적) 인식(인식) 표현수단으로서의 언어(언어).json
# load file:	SOUR004582&&& 수필론(수필론).json
# load file:	SOUR004583&&& 현대소설(현대소설)의 주인공(주인공).json
# load file:	SOUR004584&&& 시단(시단)의 신세대(신세대).json
# load file:	SOUR004585&&& 소화(소화) 13년 창작계(창작계) 개관(개관).json
# load file:	SOUR004586&&& 유치진론(柳치진론).json
# load file:	SOUR004587&&& 중견작가(중견작가) 13 인론(인론).json
# load file:	SOUR004588&&& 작품의 제작과정.json
# load file:	SOUR004589&&& 여운형.json
# load file:	SOUR004590&&& 현대여성미.json
# load file:	SOUR004591&&& 유진오 단편집.json
# load file:	SOUR004592&&& 소설(소설)과 신세대(신세대)의 성격(성격).json
# load file:	SOUR004593&&& 현실과 신세대의 시.json
# load file:	SOUR004594&&& 소설가란 직업.json
# load file:	SOUR004595&&& 나는 이렇게 소설가가 되었다.json
# load file:	SOUR004596&&& 평만 소설가와 시인(평만 소설가 와 시인).json
# load file:	SOUR004597&&& 무명 작가(무명작가) 목군(목군)에게.json
# load file:	SOUR004598&&& 백치아다다 서(서).json
# load file:	SOUR004599&&& 별을 헨다 후기(후기).json
# load file:	SOUR004600&&& 병풍에 그린 닭이 발(발).json
# load file:	SOUR004601&&& 김환기(金환기) 형(형).json
# load file:	SOUR004602&&& 나의 소설 수업.json
# load file:	SOUR004603&&& 나의 집필태도(집필태도).json
# load file:	SOUR004604&&& 어떤 무명 작가의 질문에 응하여.json
# load file:	SOUR004605&&& 작품과 기교.json
# load file:	SOUR004606&&& 작품의 구성 무시(구성무시).json
# load file:	SOUR004607&&& 제주 여자의 건강과 미.json
# load file:	SOUR004608&&& 제주 풍물 점경(제주풍물점경).json
# load file:	SOUR004609&&& 창작 일기(창작일기).json
# load file:	SOUR004610&&& 한국문단 측면사(한국문단측면사).json
# load file:	SOUR004611&&& 김동인씨의 예술전당을 파쇄.json
# load file:	SOUR004612&&& 시조(시조)의 작법.json
# load file:	SOUR004614&&& 조선근대소설고(조선근대소설고).json
# load file:	SOUR004615&&& 소설가(소설가) 지원자(지원자)에게 주는 당부.json
# load file:	SOUR004616&&& 고주몽 이야기.json
# load file:	SOUR004617&&& 날쌔고 기운 센 김덕령 김 장군 이야기.json
# load file:	SOUR004618&&& 검도령 이야기.json
# load file:	SOUR004619&&& 거북 배를 만드신 이충무공 이야기.json
# load file:	SOUR004620&&& 강감찬 장군 이야기.json
# load file:	SOUR004621&&& 세 살 때부터 글을 지은 율곡 선생 이야기.json
# load file:	SOUR004622&&& 김삿갓 이야기.json
# load file:	SOUR004623&&& 이번은 혼나던 김삿갓 이야기.json
# load file:	SOUR004624&&& 박문수이야기 - 지팡이 하나.json
# load file:	SOUR004625&&& 을지문덕 장군.json
# load file:	SOUR004626&&& 천하영웅 당 태종의 눈을 쏘아 쫓은 양만춘 장군.json
# load file:	SOUR004627&&& 천하의 강적 위나라의 이 십만 대군을 물리친 사법명대장군.json
# load file:	SOUR004628&&& 중국 천하를 쥐고 흔들던 우리 서은왕(서언왕)의 위엄.json
# load file:	SOUR004629&&& 서화담 선생 - 양(양) 처음의 대리학(대리학).json
# load file:	SOUR004630&&& 정충신 이야기 - 17세 소년장군 정충신 원사의 이야기.json
# load file:	SOUR004631&&& 고려 충신 정포은 선생과 어머니.json
# load file:	SOUR004632&&& 정몽주 선생 - 500년 전 위인 정몽주 선생 이야기.json
# load file:	SOUR004633&&& 조선의 지도와 고산자.json
# load file:	SOUR004634&&& 양만춘 장군의 안시대승.json
# load file:	SOUR004635&&& 수나라의 백만 대병을 일거에 전멸시킨 살수대첩.json
# load file:	SOUR004636&&& 천강 홍의장군.json
# load file:	SOUR004637&&& 고려 용장 강감찬 장군의 어릴 때.json
# load file:	SOUR004638&&& 철학자 이율곡 선생의 어릴 때.json
# load file:	SOUR004639&&& 만고 충신 임경업장군의 어릴 때.json
# load file:	SOUR004640&&& 만고 충용 이충무공의 어릴 때.json
# load file:	SOUR004641&&& 대 혁명가 홍경래 원사의 어릴 때.json
# load file:	SOUR004642&&& 이괄란 이야기.json
# load file:	SOUR004643&&& 임경업의 호용.json
# load file:	SOUR004644&&& 장붕익의 용맹.json
# load file:	SOUR004645&&& 김응하 장군.json
# load file:	SOUR004646&&& 궁예왕 이야기.json
# load file:	SOUR004647&&& 천도교의 시조 최수운 선생.json
# load file:	SOUR004648&&& 천하 용소년 최윤덕 장군.json
# load file:	SOUR004649&&& 홍경래 난 이야기.json
# load file:	SOUR004650&&& 맹고불 맹정승.json
# load file:	SOUR004651&&& 천하명궁 이지란 장군.json
# load file:	SOUR004652&&& 고려 용장군 김경손 - 12장사로 몽군을 대파.json
# load file:	SOUR004653&&& 정포은 (정포은).json
# load file:	SOUR004654&&& 화담 선생.json
# load file:	SOUR004655&&& 최수운 선생.json
# load file:	SOUR004656&&& 애기 장군 사다함.json
# load file:	SOUR004657&&& 문익점 선생.json
# load file:	SOUR004658&&& 을지문덕.json
# load file:	SOUR004659&&& 서경덕 선생.json
# load file:	SOUR004660&&& 온 세상을 흔들던 가난뱅이 허생원.json
# load file:	SOUR004661&&& 힘과 옳음의 덩어리 김덕령 장군.json
# load file:	SOUR004662&&& 김시습 어른.json
# load file:	SOUR004663&&& 한가위.json
# load file:	SOUR004664&&& 임경업 장군.json
# load file:	SOUR004665&&& 최영 장군.json
# load file:	SOUR004666&&& 김유신 장군.json
# load file:	SOUR004667&&& 황희 정승.json
# load file:	SOUR004668&&& 을지문덕 장군.json
# load file:	SOUR004669&&& 성삼문 어른.json
# load file:	SOUR004670&&& 소년 용사 관창.json
# load file:	SOUR004671&&& 강감찬 장군.json
# load file:	SOUR004672&&& 목화 이야기.json
# load file:	SOUR004673&&& 남이 장군.json
# load file:	SOUR004674&&& 화랑.json
# load file:	SOUR004675&&& 신라 지증왕.json
# load file:	SOUR004676&&& 박연 어른.json
# load file:	SOUR004677&&& 합소문.json
# load file:	SOUR004678&&& 근대 기걸 홍경래 장군.json
# load file:	SOUR004679&&& 창작수첩(창작수첩).json
# load file:	SOUR004680&&& 소설(소설) 안 쓰는 변명(변명).json
# load file:	SOUR004681&&& 강릉기 홍장(강릉기홍장)과 풍류순찰사(풍류순찰사).json
# load file:	SOUR004682&&& 안평대군(안평대군)의 실연(실戀).json
# load file:	SOUR004683&&& 황진이(황진이)….json
# load file:	SOUR004684&&& 철인(철인) 이토정(李토정).json
# load file:	SOUR004685&&& 갑오비화(갑오비화).json
# load file:	SOUR004686&&& 해상(해상)의 쾌인(쾌인) 안용복(안龍복).json
# load file:	SOUR004687&&& 녹두장군(녹두장군).json
# load file:	SOUR004688&&& 유방천추(유방천추).json
# load file:	SOUR004689&&& 박태보전(박태보전).json
# load file:	SOUR004690&&& 기축역괴(기축역괴) 정여립(정여립).json
# load file:	SOUR004691&&& 활인수(활인수).json
# load file:	SOUR004692&&& 명복(명복) 홍계관(홍계관).json
# load file:	SOUR004693&&& 양봉래 모친(양봉래 모친).json
# load file:	SOUR004694&&& 김총각(金총각)의 기연(기연).json
# load file:	SOUR004695&&& 상사사(상사사).json
# load file:	SOUR004696&&& 고려 태조(고려태조).json
# load file:	SOUR004697&&& 정녀사(정녀사)와 의치(의치).json
# load file:	SOUR004698&&& 김정승(金정승)과 단천기(단천기).json
# load file:	SOUR004699&&& 장대(장태)에 스러진 별.json
# load file:	SOUR004700&&& 전기(전기)와 소설(소설)의 한계성(한계성).json
# load file:	SOUR004701&&& 모방(모방)에서 창조(창조)로.json
# load file:	SOUR004702&&& 문학(문학)을 나처럼 하여서는.json
# load file:	SOUR004703&&& 조선신문학사론서설(조선신문학사론서설).json
# load file:	SOUR004704&&& 사실주의(사실주의)의 재인식(재인식).json
# load file:	SOUR004705&&& 문학사를 통해 본 여성의 비극.json
# load file:	SOUR004706&&& 논개에게.json
# load file:	SOUR004710&&& 우리 신극운동(신극운동)의 첫길.json
# load file:	SOUR004711&&& 소위(소위) 근대극(근대극)에 대(대)하여.json
# load file:	SOUR004712&&& 자유극장(자유극장) 이야기.json
# load file:	SOUR004713&&& 사옹(사옹)의 생활(생활).json
# load file:	SOUR004714&&& 구미(구미) 현대극작가(현대극작가).json
# load file:	SOUR004715&&& 쓰키지소극장(축지소극장)에서 인조인간(인조인간)을 보고.json
# load file:	SOUR004716&&& 창작(창작)을 권(권)함내다.json
# load file:	SOUR004717&&& 아관(아관) 계급문학(계급문학)과 비평가(비평가).json
# load file:	SOUR004718&&& 조선말 없는 조선문단에 일언.json
# load file:	SOUR004721&&& 몽고의 흥부 놀부.json
# load file:	SOUR004722&&& 몽고(몽고)의 박타령.json
# load file:	SOUR004723&&& 동화 (동화) 강복미복(강복미복).json
# load file:	SOUR004724&&& 민속학상(민속학상)으로 보는 단군왕검(단군왕검).json
# load file:	SOUR004725&&& 하백(하백)의 유래(유래).json
# load file:	SOUR004726&&& 충무공(충무공)과 그 소실(소실).json
# load file:	SOUR004727&&& 조선(조선)과 서양(서양)과의 설화상(설화상) 교섭(교섭).json
# load file:	SOUR004728&&& 조선(조선)의 신화(신화).json
# load file:	SOUR004729&&& 조선(조선)의 신화(신화)와 일본(일본)의 신화(신화).json
# load file:	SOUR004730&&& 조선(조선)의 화수분.json
# load file:	SOUR004731&&& 조선민담(조선민담)의 세계적(세계적) 배경(배경).json
# load file:	SOUR004732&&& 조선민담(조선민담)의 양대장격(兩대장격)인 범과 도깨비.json
# load file:	SOUR004733&&& 조선사상(조선사상) 세계적(세계적) 사실(사실).json
# load file:	SOUR004734&&& 조선사(조선사)의 기자(기자)는 지나(지나)의 기자(기자)가 아니다.json
# load file:	SOUR004735&&& 임경업장군(林경업장군).json
# load file:	SOUR004736&&& 깨트려지는 홍등의 평을 읽고.json
# load file:	SOUR004737&&& 작가 단편 자서전.json
# load file:	SOUR004738&&& 소하일기(소하일기).json
# load file:	SOUR004739&&& 온달열전(온달列전).json
# load file:	SOUR004740&&& 외국(외국)으로서 귀화(귀화)한 조선고담(조선고담).json
# load file:	SOUR004741&&& 안식국(안식국)에 연락(蓮락) 있는 지봉유설(지봉류설)의 일사인(일사인).json
# load file:	SOUR004743&&& 선녀우의전설(선여우의전설).json
# load file:	SOUR004744&&& 설씨가실(설씨가실)의 합경기연(합경기연).json
# load file:	SOUR004745&&& 선경(선경) 이야기.json
# load file:	SOUR004746&&& 시베리아 바이칼호를 지나며.json
# load file:	SOUR004747&&& 백양사에서.json
# load file:	SOUR004748&&& 약산동대(약산동대).json
# load file:	SOUR004749&&& 약산동대(약산동대)에 피는 진달래.json
# load file:	SOUR004750&&& 계변정화(계변정화).json
# load file:	SOUR004751&&& 5천리의 남지나해.json
# load file:	SOUR004752&&& 금정산(금정산)의 진달래.json
# load file:	SOUR004753&&& 꽃지는 남국에.json
# load file:	SOUR004754&&& 찔레꽃 피는 첫여름의 강가.json
# load file:	SOUR004755&&& 단풍잎이 고운 9월.json
# load file:	SOUR004756&&& 내 고향 신화리.json
# load file:	SOUR004757&&& 금계산의 반달 못.json
# load file:	SOUR004758&&& 소설학도(소설학도)의 서재(서재)에서.json
# load file:	SOUR004759&&& 적막(적막)한 예원(예원).json
# load file:	SOUR004760&&& 문학인(문학인)의 촉감(촉감).json
# load file:	SOUR004763&&& 조선역사(조선歷사) 급(급) 민속사상(민속사상)의 호(호).json
# load file:	SOUR004765&&& 호랑이의 변화(변화).json
# load file:	SOUR004766&&& 예술(예술)의 사실성(사실성).json
# load file:	SOUR004767&&& 사람의 사는 참 모양.json
# load file:	SOUR004768&&& 결전하(결전하) 문단인(문단인)의 결의(결의).json
# load file:	SOUR004769&&& 편주(편주)의 가는 곳.json
# load file:	SOUR004770&&& 나의 변명 - 발가락이 닮았다에 대하여.json
# load file:	SOUR004771&&& 학병 수첩.json
# load file:	SOUR004772&&& 민족문학(민족문학)과 무산문학(무산문학)의 합치점(합치점)과 차이점(차이점).json
# load file:	SOUR004773&&& 근대소설(근대소설)의 승리(승리).json
# load file:	SOUR004775&&& 소설에 대한 조선 사람의 사상을.json
# load file:	SOUR004776&&& 조선사(조선사)의 개관(개관).json
# load file:	SOUR004777&&& 조선미술사요(조선미술사요).json
# load file:	SOUR004778&&& 조선(조선) 무예고(무예고).json
# load file:	SOUR004779&&& 심(沈) 봉사.json
# load file:	SOUR004780&&& 백마강(백마강)의 뱃놀이.json
# load file:	SOUR004781&&& 오월(오월) 가두풍경(가두풍경).json
# load file:	SOUR004782&&& 기미(기미) 3·1날.json
# load file:	SOUR004783&&& 변태심리(변태심리).json
# load file:	SOUR004784&&& 김동인(金동인)씨에게.json
# load file:	SOUR004785&&& 소포클레스로부터 고리키까지.json
# load file:	SOUR004786&&& 6월의 아침.json
# load file:	SOUR004787&&& 인형의 집을 나와서.json
# load file:	SOUR004788&&& 역사와 사실과 판단과 사료에 대한 작자의 입장을 논함.json
# load file:	SOUR004789&&& 강선달.json
# load file:	SOUR004790&&& 금 빛 오월.json
# load file:	SOUR004791&&& 연분홍 나체(裸체).json
# load file:	SOUR004792&&& 8·15와 순사(순사).json
# load file:	SOUR004793&&& 8·15와 한글.json
# load file:	SOUR004794&&& 8·15 전후(전후).json
# load file:	SOUR004795&&& 갑오(갑오) 광복절(광復절).json
# load file:	SOUR004796&&& 갑오(갑오) 삼일절(삼일절).json
# load file:	SOUR004797&&& 계급문학시비론(계급문학시비論).json
# load file:	SOUR004798&&& 고리끼에 관한 단상.json
# load file:	SOUR004799&&& 고리끼의 사후 1주년.json
# load file:	SOUR004800&&& 고리끼의 세계문학적 지위.json
# load file:	SOUR004801&&& 배비장(배비장).json
# load file:	SOUR004802&&& 백발홍장(백발홍장).json
# load file:	SOUR004803&&& 불국사(불국사) 석불사(석불사) 연기(연기).json
# load file:	SOUR004804&&& 흥보씨(흥보씨).json
# load file:	SOUR004806&&& 1905년 전(전)의 고리키.json
# load file:	SOUR004807&&& 3·1운동과 나.json
# load file:	SOUR004808&&& 3월 1일이 온다.json
# load file:	SOUR004809&&& 12월과 나.json
# load file:	SOUR004810&&& 간도행(간도행).json
# load file:	SOUR004811&&& 고조선(고조선)에 있어서의 정치규범(정치규범).json
# load file:	SOUR004812&&& 고전(고전)에의 귀환.json
# load file:	SOUR004813&&& 모던 문예사전.json
# load file:	SOUR004814&&& 명태(명태).json
# load file:	SOUR004815&&& 문단(문단) 15년(십오년) 이면사(裏면사).json
# ...
# load file:	SOUR008292&&& 차(다)와 나.json
# load file:	SOUR008294&&& 차라리 달 없는 밤이드면.json
# load file:	SOUR008295&&& 차방(茶방).json
# load file:	SOUR008297&&& 찬 달밤에.json
# load file:	SOUR008298&&& 찬가.json
# load file:	SOUR008299&&& 찬물(찬물).json
# load file:	SOUR008300&&& 참혹한 얼굴이여.json
# load file:	SOUR008301&&& 참회(참회).json
# load file:	SOUR008302&&& 충주(충주) 탄금대(탄금태).json
# load file:	SOUR008303&&& 춘향전과 이본문제 - 염정소설 시비.json
# load file:	SOUR008304&&& 춘향전.json
# load file:	SOUR008305&&& 춘향전 해석.json
# load file:	SOUR008306&&& 채전(채전).json
# load file:	SOUR008307&&& 금오신화(금오신화)에 대(대)한 약간(약간)의 소평(소평).json
# load file:	SOUR008309&&& 춘향전과 이본문제 - 조문판(조문판)과 박씨본(박씨본).json
# load file:	SOUR008310&&& 조선 연문학의 최고봉 「변강쇠전」.json
# load file:	SOUR008311&&& 춘향전과 이본문제 - 한문본과 언문본.json
# load file:	SOUR008312&&& 조선고대소설연구 - 장화홍련전(장화홍련전).json
# load file:	SOUR008313&&& 조선고대소설연구 - 흥부전(흥부전).json
# load file:	SOUR008314&&& 조선고대소설연구 - 장끼전.json
# load file:	SOUR008315&&& 조선고대소설연구 - 토끼전.json
# load file:	SOUR008316&&& 조선고대소설연구 - 홍길동전(홍길동전).json
# load file:	SOUR008317&&& 조선고대소설연구 - 유충렬전(劉충렬전).json
# load file:	SOUR008318&&& 조선고대소설연구 - 박씨전(박씨전).json
# load file:	SOUR008319&&& 조선고대소설연구 - 창선감의록(창선감의록).json
# load file:	SOUR008320&&& 조선고대소설연구 - 사씨남정기(사씨남정기).json
# load file:	SOUR008321&&& 서재탐방기 - 이병기(李병기) 선생(선생).json
# load file:	SOUR008322&&& 이 고사본(고사본)에 대(대)하야.json
# load file:	SOUR008323&&& 『청구영언(청구영언)』 서언(서언).json
# load file:	SOUR008324&&& 고대소설(고대소설)의 대중성(대중성).json
# load file:	SOUR008325&&& 민족문학(민족문학)과 민족주의문학(민족주의문학).json
# load file:	SOUR008326&&& 영화(영화) 무정(무정)의 인상(인상).json
# load file:	SOUR008327&&& 영화촌경(영화촌경).json
# load file:	SOUR008328&&& 임진왜란(임진왜란)과 사대주의(사대주의) - 외력(외력) 의존(의존)의 교훈(교훈).json
# load file:	SOUR008329&&& 정감록(정감록)의 과학적(과학적) 비판(비판).json
# load file:	SOUR008331&&& 개시대길(개시대길).json
# load file:	SOUR008332&&& 고교형(고교형) 선생(선생)의 프로필.json
# load file:	SOUR008333&&& 현대지나(현대지나)의 신진작가(신진작가).json
# load file:	SOUR008334&&& 태몽(태몽).json
# load file:	SOUR008339&&& 종로(종로) 네 거리.json
# load file:	SOUR008340&&& 승강기(승강기).json
# load file:	SOUR008341&&& 양녕대군(양령대군)의 종손(종손).json
# load file:	SOUR008342&&& 향토(향토)의 동요(동요).json
# load file:	SOUR008343&&& 나폴레온 소론(소론 ).json
# load file:	SOUR008344&&& 봄, 속(속) 된 봄.json
# load file:	SOUR008345&&& 복수(復수).json
# load file:	SOUR008346&&& 소설(소설) 빵떡.json
# load file:	SOUR008347&&& 압록강상(압록강상).json
# load file:	SOUR008349&&& 노신(魯신)에 대(대)하야.json
# load file:	SOUR008350&&& 노신(魯신)의 문학관(문학관) ∶ 문예비평(문예비평)에 대(대)하야.json
# load file:	SOUR008351&&& 고향(고향).json
# load file:	SOUR008352&&& 고향(고향)의 「호서가(호서가)」.json
# load file:	SOUR008354&&& 노신(魯신) 부인(부인) 경송여사(경송여사)의 프로필.json
# load file:	SOUR008355&&& 노신(魯신) 선생(선생)의 부인(부인) 허경송(허경송) 여사(여사).json
# load file:	SOUR008356&&& 임진란(임진란)과 전설(전설).json
# load file:	SOUR008357&&& 중국(중국)의 항전문학(항전문학) - 국방문학(국방문학).json
# load file:	SOUR008358&&& 촌산지의씨(촌산지의씨)에게 - 춘향전 영화화(춘향전 영화화)을 앞두고.json
# load file:	SOUR008359&&& 중국(중국)의 신문학혁명(신문학혁명)의 교훈(교훈).json
# load file:	SOUR008360&&& 중국(중국)의 여성(여성) 해방(해방).json
# load file:	SOUR008361&&& 지나(지나)의 신진작가(신진작가) 소군(소군)의 작품(작풍).json
# load file:	SOUR008362&&& 무엇보다도 자존심(자존심)을.json
# load file:	SOUR008363&&& 지식(지식).json
# load file:	SOUR008364&&& 학생(학생)과 교양(교양).json
# load file:	SOUR008365&&& 학생란(학생란)에의 환호(환호) - 쌍수(쌍수)들어 환영(환영).json
# load file:	SOUR008366&&& 현대(현대) 학생(학생)의 면모(면모).json
# load file:	SOUR008367&&& 용어해설 '듸렛탄트'.json
# load file:	SOUR008368&&& 이상(理상)도 정열(정열)도 시(시)조차 업는 풍경(풍경).json
# load file:	SOUR008369&&& 논설(論설) ∶ '고맙습니다' 와 감사(감사)의 생활(생활).json
# load file:	SOUR008370&&& 노신(魯신)의 미성작품(미성작품).json
# load file:	SOUR008372&&& 이춘풍전(李춘풍전)의 현대화(현대화).json
# load file:	SOUR008375&&& 가사수집(가사수집) (기일(기일)) 영산가(靈산가).json
# load file:	SOUR008378&&& 조선동요자료집(조선동요자료집) - 동요(동요) 3.json
# load file:	SOUR008379&&& 맨발.json
# load file:	SOUR008380&&& 닭.json
# load file:	SOUR008381&&& 목양애가(목양애가).json
# load file:	SOUR008382&&& 전국문학자대회 축사.json
# load file:	SOUR008383&&& 상해사변의 회고.json
# load file:	SOUR008395&&& 1933.6.1.json
# load file:	SOUR008396&&& I WED A TOY BRIDE.json
# load file:	SOUR008397&&& 꽃나무.json
# load file:	SOUR008398&&& 추등잡필(추등잡필).json
# load file:	SOUR008399&&& 퇴주수난기(퇴주수난기).json
# load file:	SOUR008644&&& 꿀벌의 마음.json
# load file:	SOUR008645&&& 나비와 가락지꽃.json
# load file:	SOUR008646&&& 분꽃 이야기.json
# load file:	SOUR008647&&& 어미소와 새끼소.json
# load file:	SOUR008648&&& 백일홍 이야기.json
# load file:	SOUR008649&&& 옥희와 금붕어.json
# load file:	SOUR008650&&& 아기의 꿈.json
# load file:	SOUR008651&&& 엄마 없는 작은 새.json
# load file:	SOUR008652&&& 노래 부르는 꽃.json
# load file:	SOUR008653&&& 보석속에 공주.json
# load file:	SOUR008654&&& 바위의 슬픔.json
# load file:	SOUR008656&&& 꼽추 이야기.json
# load file:	SOUR008657&&& 네 힘껏 했다.json
# load file:	SOUR008658&&& 국기 소녀.json
# load file:	SOUR008659&&& 5인 동무.json
# load file:	SOUR008660&&& “나 몰라”의 죽음.json
# load file:	SOUR008661&&& 자동차 3등.json
# load file:	SOUR008662&&& 재판장의 빨간 코.json
# load file:	SOUR008663&&& 라인 강가의 형제.json
# load file:	SOUR008664&&& 로-헨그린.json
# load file:	SOUR008665&&& 『아드와』의 원수를!.json
# load file:	SOUR008666&&& 태양의 풍속 (김기림시집).json
# load file:	SOUR008667&&& 오월(오월)의 마음.json
# load file:	SOUR008668&&& 가을밤.json
# load file:	SOUR008669&&& 가을의 단상(단상).json
# load file:	SOUR008687&&& 『삼광』 창간의 변.json
# load file:	SOUR008688&&& 기러기.json
# load file:	SOUR008689&&& 로렐라이의 유래.json
# load file:	SOUR008690&&& 리스트의 국제적 연애.json
# load file:	SOUR008691&&& 마스카니의 제자.json
# load file:	SOUR008692&&& 마왕(마왕)의 작곡.json
# load file:	SOUR008693&&& 모짜르트의 실연(실戀).json
# load file:	SOUR008694&&& 문지기과의 대화.json
# load file:	SOUR008695&&& 문호(문호) 시성(시성)의 음악관.json
# load file:	SOUR008696&&& 벨리니의 비련.json
# load file:	SOUR008697&&& 세익스피어와 음악.json
# load file:	SOUR008698&&& 쇼팽과 그의 연인.json
# load file:	SOUR008699&&& 시카고광상곡(시아고광상곡).json
# load file:	SOUR008700&&& 영웅 교향곡(영웅 교향곡).json
# load file:	SOUR008701&&& 월광의 곡.json
# load file:	SOUR008702&&& 이별의 소야곡.json
# load file:	SOUR008703&&& 병정나팔.json
# load file:	SOUR008704&&& 해바라기.json
# load file:	SOUR008705&&& 편지.json
# load file:	SOUR008706&&& 새로운 조선음악.json
# load file:	SOUR008711&&& 구름의 철학(철학).json
# load file:	SOUR008712&&& 가을.json
# load file:	SOUR008713&&& 가을.json
# load file:	SOUR008714&&& 떨어지는 가을.json
# load file:	SOUR008715&&& 가는 가을.json
# load file:	SOUR008716&&& 가을 가을 재미.json
# load file:	SOUR008717&&& 가을 강(강)가에 시드러져가는 당(당)버들을 보앗노라.json
# load file:	SOUR008718&&& 석우노(석우로)의 처(처).json
# load file:	SOUR008719&&& 승암(승암)의 괴녀(괴녀).json
# load file:	SOUR008722&&& 충용 삼형제(충용 삼형제).json
# load file:	SOUR008723&&& 건국과 정치문화, 노선.json
# load file:	SOUR008724&&& 건국과업에 대한 사견 (시론).json
# load file:	SOUR008725&&& 건국동맹.json
# load file:	SOUR008729&&& 공위는 성공한다.json
# load file:	SOUR008730&&& 공위의 협상대상.json
# load file:	SOUR008734&&& 미소공위 무기휴회에 대해.json
# load file:	SOUR008740&&& 김동환의 편지 내용.json
# load file:	SOUR008741&&& 나의 전진목표.json
# load file:	SOUR008742&&& 조선독립의 당위성 (대담).json
# load file:	SOUR008743&&& 청년에게 보내는 말.json
# load file:	SOUR008744&&& 현대청년론.json
# load file:	SOUR008745&&& 청년 솔로호프.json
# load file:	SOUR008746&&& 음락잡신[음악잡신]. 특히음악청년 제군에게.json
# load file:	SOUR008747&&& 조선청년에게 부탁한다.json
# load file:	SOUR008748&&& 청년적(청년적) 정열(정열)이 필요(필요).json
# load file:	SOUR008749&&& 타락된 창작 풍조에 반성 - 『취향(취향)』 독후감 -.json
# load file:	SOUR008751&&& 회상의 명화선.json
# load file:	SOUR008752&&& 황금아(Golden-boy).json
# load file:	SOUR008753&&& 회상의 긴 계곡.json
# load file:	SOUR008754&&& 현대 영화의 감각.json
# load file:	SOUR008755&&& 한줄기 눈물도 없이.json
# load file:	SOUR008756&&& 투명한 버라이어티.json
# load file:	SOUR008757&&& 침울한 바다.json
# load file:	SOUR008758&&& 『새로운 도시와 시민들의 합창』 서문.json
# load file:	SOUR008759&&& 『신시론』 후기.json
# load file:	SOUR008760&&& 「제니의 초상」 감상.json
# load file:	SOUR008761&&& 「챔피언」.json
# load file:	SOUR008763&&& 거리.json
# load file:	SOUR008764&&& 남풍.json
# load file:	SOUR008765&&& 눈을 뜨고도.json
# load file:	SOUR008766&&& 무도회.json
# load file:	SOUR008767&&& 밴 플리트 장군과 시.json
# load file:	SOUR008768&&& 식물.json
# load file:	SOUR008769&&& 식민항의 밤.json
# load file:	SOUR008770&&& 인도네시아 인민에게 주는 시.json
# load file:	SOUR008771&&& 즐겁지 않은 계절.json
# load file:	SOUR008772&&& 최후의 회화(회화).json
# load file:	SOUR008773&&& 충혈된 눈동자.json
# load file:	SOUR008779&&& 서부전선에서.json
# load file:	SOUR008780&&& 보도사진 잡고.json
# load file:	SOUR008781&&& 그들은 왜 밀항하였나？.json
# load file:	SOUR008782&&& 기적인 현대.json
# load file:	SOUR008784&&& 몇 가지의 노트.json
# load file:	SOUR008785&&& 미국에 사는 한국 이민.json
# load file:	SOUR008786&&& 밤의 미매장(미매장).json
# load file:	SOUR008787&&& 시네마스코프의 문제.json
# load file:	SOUR008788&&& 앙케트.json
# load file:	SOUR008789&&& 최근의 외국 영화 수준.json
# load file:	SOUR008790&&& 권력과 아부(아부).json
# load file:	SOUR008791&&& 설수집(설수집).json
# load file:	SOUR008792&&& 거울.json
# load file:	SOUR008793&&& 가지가지의 기형아(기형아).json
# load file:	SOUR008794&&& 거인(거인)· 장인(장인)· 대인(대인).json
# load file:	SOUR008795&&& 노래 이야기.json
# load file:	SOUR008796&&& 대조선정신(대조선정신).json
# load file:	SOUR008797&&& 타출(타출)의 소퇴(소퇴) 예화(例화).json
# load file:	SOUR008798&&& 현실불여의(현실불여의)의 반영(반영).json
# load file:	SOUR008799&&& 대중적(대중적) 요구(요구)의 반영(반영).json
# load file:	SOUR008800&&& 라브라 왕(왕)의 사적(사적).json
# load file:	SOUR008801&&& 레이븐과 경인(경인).json
# load file:	SOUR008802&&& 명월주(명월주)· 야광벽(야광벽).json
# load file:	SOUR008803&&& 물네방아.json
# load file:	SOUR008804&&& 백조처녀형(백조처녀형).json
# load file:	SOUR008805&&& 보배.json
# load file:	SOUR008806&&& 애(애) 강우당(강우당).json
# load file:	SOUR008807&&& 애(애) 권일재(권일재).json
# load file:	SOUR008808&&& 애(애) 김인촌(金인촌)(성수(성수)).json
# load file:	SOUR008809&&& 애(애) 변산강(변산강)(영만(영만)).json
# load file:	SOUR008810&&& 애(애) 신해공(신해공).json
# load file:	SOUR008811&&& 애란(애란) 미크의 병(병).json
# load file:	SOUR008812&&& 여자(여자)의 이인(이인).json
# load file:	SOUR008813&&& 양녕(양령)과 정향(정향).json
# load file:	SOUR008814&&& 호미부(호미부) 이제(이제).json
# load file:	SOUR008815&&& 눈 오는 대궐(대궐).json
# load file:	SOUR008816&&& 거타지(거타지)의 꽃.json
# load file:	SOUR008817&&& 후백제비화(후백제비화).json
# load file:	SOUR008818&&& 순정의 호동왕자(호동왕자).json
# load file:	SOUR008819&&& 정열의 낙랑공주(樂랑공주).json
# load file:	SOUR008820&&& 홍윤성(홍윤성)과 절부(절부).json
# load file:	SOUR008821&&& 괴승(괴승) 신수(신수).json
# load file:	SOUR008822&&& 경벌포의(경벌포의).json
# load file:	SOUR008823&&& 초췌연화편(초췌蓮화편).json
# load file:	SOUR008824&&& 보은단 유래(보은단유래).json
# load file:	SOUR008825&&& 사각전기 (사각전기).json
# load file:	SOUR008826&&& 상방기현(상방기현).json
# load file:	SOUR008827&&& 소설정획점고인(소설정획점고인).json
# load file:	SOUR008828&&& 안류정(안류정).json
# load file:	SOUR008829&&& 우연의 기적(기적).json
# load file:	SOUR008830&&& 원수(원수)로 은인(은인).json
# load file:	SOUR008831&&& 이식과 도승(도승).json
# load file:	SOUR008832&&& 적괴유의(적괴유의).json
# load file:	SOUR008833&&& 투환금은(투환금은).json
# load file:	SOUR008834&&& 한말상계관견록(한말상계관견록).json
# load file:	SOUR008835&&& 장마가 실어온 발복(발복).json
# load file:	SOUR008836&&& 종침교명명유래기(종침교명명유래기).json
# load file:	SOUR008837&&& 집념(집념).json
# load file:	SOUR008838&&& 식철수(식철수).json
# load file:	SOUR008839&&& 적분재상(적분재상).json
# load file:	SOUR008840&&& 탐라 점철(탐라점철) 초(초).json
# load file:	SOUR008841&&& 나의 취미.json
# load file:	SOUR008842&&& 내가 사는 주변.json
# load file:	SOUR008843&&& 낚시.json
# load file:	SOUR008844&&& 내 붓끝은 먼 산을 바라본다.json
# load file:	SOUR008845&&& 거초(거초) 꺾일 때.json
# load file:	SOUR008846&&& 반야(반약)의 죽음.json
# load file:	SOUR008847&&& 화하난무(화하란무).json
# load file:	SOUR008848&&& 왕기(왕기)는 벋어서.json
# load file:	SOUR008849&&& 고달산(고달산).json
# load file:	SOUR008850&&& 두문동록(두문동록).json
# load file:	SOUR008851&&& 수양(수양).json
# load file:	SOUR008852&&& 신문고(신문고).json
# load file:	SOUR008853&&& 대수양(대수양).json
# load file:	SOUR008854&&& 여인담(여인담).json
# load file:	SOUR008855&&& 임장군(임장군).json
# load file:	SOUR008856&&& 술값 외상.json
# load file:	SOUR008857&&& 배회.json
# load file:	SOUR008858&&& 전제자(전제자).json
# load file:	SOUR008862&&& 가시리 평설(평설).json
# load file:	SOUR008863&&& 1927년 문단의 총결산.json
# load file:	SOUR008864&&& 각계척후(각계척후).json
# load file:	SOUR008865&&& 계급문학과 그 비판적 요소.json
# load file:	SOUR008866&&& 1월 창작평 - 실증문학을 기초로한 구성적 월평.json
# load file:	SOUR008867&&& 각서사속(각서사속).json
# load file:	SOUR008868&&& 계급예술의 신전개를 읽고.json
# load file:	SOUR008869&&& 당면문제의 수삼(수삼).json
# load file:	SOUR008870&&& 덕수궁 석조전의 일본미술을 보고.json
# load file:	SOUR008871&&& 동화연구의 일 단면, 동화집 『금쌀애기』를 읽고.json
# load file:	SOUR008872&&& 맑스 경제론과 크로포트킨의 비판.json
# load file:	SOUR008873&&& 맑스주의 문학론 음미.json
# load file:	SOUR008874&&& 무산계급의 심미감.json
# load file:	SOUR008875&&& 무산계급의 예술.json
# load file:	SOUR008876&&& 무산문학가의 창작적 태도.json
# load file:	SOUR008877&&& 문단시언(문단시언) - 최근 문예 단상.json
# load file:	SOUR008878&&& 문단촌언 - 신년을 맞으며.json
# load file:	SOUR008879&&& 문예시평.json
# load file:	SOUR008880&&& 문예시평 - 5월 창작개평.json
# load file:	SOUR008884&&& 현단계 조선사람은 어떠한 문학을 요구하는가 - 문학 아닌 문학.json
# load file:	SOUR008885&&& 문학작품의 방법론적 연구.json
# load file:	SOUR008886&&& 미술강좌 - 선사시대 회화사.json
# load file:	SOUR008887&&& 민촌 형에게.json
# load file:	SOUR008888&&& 상경(상경), 구걸(구걸), 귀향(귀향).json
# load file:	SOUR008889&&& 껍데기는 가라.json
# load file:	SOUR008892&&& 상호비판과 이론확립.json
# load file:	SOUR008893&&& 생활, 의식, 동지.json
# load file:	SOUR008894&&& 소화(소화) 십일년도 조선문학의 동향(앙케이트).json
# load file:	SOUR008895&&& 속수 인물화 강의.json
# load file:	SOUR008896&&& 신 유행 예상기, 새해에 올 유행 중의 한 가지.json
# load file:	SOUR008897&&& 신문삽화 만평.json
# load file:	SOUR008898&&& 실천적 행위.json
# load file:	SOUR008903&&& 여류투사(여류투사) 루이스의 편영(편영).json
# load file:	SOUR008904&&& 여성운동의 일고찰.json
# load file:	SOUR008905&&& 영화시평(영화시평) (1929년 3월).json
# load file:	SOUR008906&&& 영화시평(영화시평) (1929년 4월).json
# load file:	SOUR008907&&& 영화이론과 비평의 근본적 의의.json
# load file:	SOUR008908&&& 예술 활동의 제 문제.json
# load file:	SOUR008909&&& 예술운동의 신전개.json
# load file:	SOUR008910&&& 우상의 문제에 관한 이론과 실제.json
# load file:	SOUR008911&&& 우상의 문제에 대하여.json
# load file:	SOUR008912&&& 위대한 세계적 문호.json
# load file:	SOUR008913&&& 이기영씨의 창작집 『민촌』을 읽고.json
# load file:	SOUR008914&&& 이론투쟁과 실천과정.json
# load file:	SOUR008915&&& 자유연애 사상과 성교육문제에 대하여.json
# load file:	SOUR008916&&& 전기적 프로예술.json
# load file:	SOUR008917&&& 조선 문예이론은 어디로 귀결될까(앙케이트).json
# load file:	SOUR008918&&& 조선미전 단평.json
# load file:	SOUR008919&&& 조선영화의 제작경향.json
# load file:	SOUR008920&&& 창작가로서 김남천(金남천) 군의 인상.json
# load file:	SOUR008921&&& 최근 문예 잡감.json
# load file:	SOUR008922&&& 팔려가는 개.json
# load file:	SOUR008923&&& 포석 군의 『직업노동문예작품』을 읽고.json
# load file:	SOUR008924&&& 연극인 김복진.json
# load file:	SOUR008925&&& 흑야숭배(흑야숭배).json
# load file:	SOUR008926&&& 공방에 들어박혀 흙장난이나 합지요.json
# load file:	SOUR008927&&& 나형 선언 초안(裸형선언초안).json
# load file:	SOUR008928&&& 단평.json
# load file:	SOUR008929&&& 미전 제5회 단평.json
# load file:	SOUR008930&&& 제4회 미전 인상기.json
# load file:	SOUR008931&&& 제7회 미전 인상평.json
# load file:	SOUR008932&&& 제19회 조선미전 인상기.json
# load file:	SOUR008933&&& 정축 조선 미술계 대관.json
# load file:	SOUR008934&&& 미전을 보고 나서.json
# load file:	SOUR008935&&& 선전(선전)의 성격.json
# load file:	SOUR008936&&& 조선 역사 그대로의 반영인 조선미술의 윤곽.json
# load file:	SOUR008937&&& 조각생활 20년기.json
# load file:	SOUR008938&&& 최고의 아름다운 포즈.json
# load file:	SOUR008939&&& 동경 미술 학생전 일별.json
# load file:	SOUR008940&&& 명사 만문만답(만문만답).json
# load file:	SOUR008941&&& 신흥 미술과 그 표적.json
# load file:	SOUR008942&&& 예술관념과 윤리관념은 공간(적배)의 양단(양단)이다.json
# load file:	SOUR008943&&& 재동경 미술 학생의 종합전 인상기.json
# load file:	SOUR008944&&& 조선 조각도의 향방.json
# load file:	SOUR008945&&& 조선화단의 일년.json
# load file:	SOUR008946&&& 협전 5회평.json
# load file:	SOUR008947&&& 거울.json
# load file:	SOUR008948&&& 무제(무제).json
# load file:	SOUR008949&&& 추억.json
# load file:	SOUR008950&&& 코스모스.json
# load file:	SOUR008951&&& 황금(황금)의 임금(林금).json
# load file:	SOUR008952&&& 황혼(황혼).json
# load file:	SOUR008953&&& 고뇌와 인생(인생).json
# load file:	SOUR008954&&& 녹색의 계곡.json
# load file:	SOUR008955&&& 녹음의 낙원에서.json
# load file:	SOUR008956&&& 누님.json
# load file:	SOUR008957&&& 눈물에 젖은 패배자.json
# load file:	SOUR008958&&& 당신 창옆에 우는 한마리 새!.json
# load file:	SOUR008959&&& 동경시대(동경시대).json
# load file:	SOUR008960&&& 동쪽 정원에 핀꽃.json
# load file:	SOUR008961&&& 행복의 문은 영원하다.json
# load file:	SOUR008962&&& 행복의 촛불.json
# load file:	SOUR008964&&& 개 싸움.json
# load file:	SOUR008965&&& 시집가는 시악시의 말.json
# load file:	SOUR008966&&& 부엉이 운다.json
# load file:	SOUR008967&&& 을해시단총평(을해시단총평).json
# load file:	SOUR008968&&& 편집잔영(편집잔영).json
# load file:	SOUR008978&&& 만폭동(만폭동).json
# load file:	SOUR008979&&& 서울의 거리.json
# load file:	SOUR008980&&& 궁인창(궁인창).json
# load file:	SOUR008981&&& 마주석(마주석).json
# load file:	SOUR009002&&& 방서한(방서한).json
# load file:	SOUR009045&&& 고독(고독).json
# load file:	SOUR009046&&& 가정(가정).json
# load file:	SOUR009047&&& 정부(정부) 춘향가(춘향가).json
# load file:	SOUR009048&&& 슬픈 모순.json
# load file:	SOUR009049&&& 여학생과 금시계.json
# load file:	SOUR009054&&& 중국은 어디로 가나.json
# load file:	SOUR009055&&& 모(모)된 감상기(감상기).json
# load file:	SOUR009056&&& 보월(보월).json
# load file:	SOUR009057&&& 벨지엄의 용사(용사).json
# load file:	SOUR009058&&& 긴 숙시(숙시).json
# load file:	SOUR009059&&& 조(조)에 접(접).json
# load file:	SOUR009060&&& 이상의 문학의 한 모.json
# load file:	SOUR009075&&& 멧새 소리.json
# load file:	SOUR009076&&& 개척자(개척자).json
# load file:	SOUR009077&&& 사랑의 동명왕.json

# %%
'''
    pattern
    1   -   처럼
    2   -   같은

    참고 : https://encykorea.aks.ac.kr/Article/E0054525
'''

# %% [markdown]
# ### 패턴 1 '처럼' 에 대해서 보조관념 추출

# %%
# choose sentences by pattern1
pattern1 = {}
for writing in writings : 
    for sentence in writing['sentences'] :
        if len(sentence) <= 0 : break
        if len(sentence) >= 1000 : break

        sentence = remove_ss(sentence)

        tokens = []
        if '처럼' in sentence : 
            tokens = KIWI.analyze(sentence)[0][0]
        
        if len(tokens) != 0 :
            pattern1[sentence] = {'tokens': tokens_to_list_of_dict(tokens)}
# Out:
# C:\Users\boong\AppData\Local\Temp\ipykernel_2068\3806690218.py:13: FutureWarning: Possible nested set at position 1
#   p = re.compile(r'[[|{|()}].+?[]|}|)]')

# %%
# save pattern1 sentences
with open(PATH2+'/pattern1.json', 'w', encoding='utf-8') as file :
    json.dump(pattern1, file, indent='\t', ensure_ascii=False)

# %%
# load pattern1 sentences
pattern1 = None
with open(PATH2+'/pattern1.json', 'r', encoding='utf-8') as file : 
    pattern1 = json.load(file)

# %%
# extract auxiliary ideas from pattern1 sentences
auxiliary_ideas = {}

for key, value in pattern1.items() :
    sentence = key
    tokens = value['tokens']
    
    # find pos token of pattern1
    pattern_indexes = []
    for i in range(len(tokens)) :
        token = tokens[i]
        if token['form'] == '처럼' and token['tag'] == 'JKB' :
            pattern_indexes.append(i)
    
    # find auxiliary idea pos token of pattern1
    for index in pattern_indexes :
        auxiliary_idea = []

        auxiliary_idea.insert(0, tokens[index])

        index = index-1
        current = tokens[index]
        if current['tag'] not in ['NNG', 'NNP', 'NR', 'NP', 'NNB'] : 
            current = None

        while current != None : 
            auxiliary_idea.insert(0, current)
            
            if index == 0 : 
                break

            current_tag = current['tag']
            next_tag = tokens[index-1]['tag']
            
            # S1
            if current_tag in ['NNB'] :
                if next_tag in ['JKG', 'MM', 'ETM'] : 
                    index = index-1
                    current = tokens[index]
                else :
                    del auxiliary_idea[0]
                    current = None
            # S2
            if current_tag in ['XSN'] :
                nnext_tag = tokens[index-2]['tag']
                if next_tag in ['XR'] :
                    if next_tag in ['NNB', 'XSN', 'NNG', 'NNP', 'NR', 'NP', 'ETN', 'JKG', 'MM', 'ETM'] :
                        auxiliary_idea.insert(0, tokens[index-1])
                        index = index-2
                        current = tokens[index]
                    else :
                        current = None
                else :
                    del auxiliary_idea[0]
                    current = None
            # S3 - Can Move Termination
            if current_tag in ['NNG', 'NNP', 'NR', 'NP'] :
                if next_tag in ['NNB', 'XSN', 'NNG', 'NNP', 'NR', 'NP', 'XPN', 'ETN', 'JKG', 'MM', 'ETM'] :
                    index = index-1
                    current = tokens[index]
                else :
                    current = None
            # S4
            if current_tag in ['ETN'] :
                if next_tag in ['VV', 'VV-I', 'VV-R', 'VA', 'VA-I', 'VA-R', 'VX', 'VX-I', 'VX-R'] : 
                    index = index-1
                    current = tokens[index]
                else :
                    del auxiliary_idea[0]
                    current = None
            # S5 - Can Move Termination
            if current_tag in ['XPN'] :
                if next_tag in ['NNB', 'XSN', 'NNG', 'NNP', 'NR', 'NP', 'ETN', 'JKG', 'MM', 'ETM'] : 
                    index = index-1
                    current = tokens[index]
                else :
                    current = None
            # S6
            if current_tag in ['VX', 'VX-I', 'VX-R'] :
                if next_tag in ['EC'] :
                    index = index-1
                    current = tokens[index]
                else :
                    del auxiliary_idea[0]
                    del auxiliary_idea[0]
                    current = None
            # S7 
            if current_tag in ['EC'] :
                if next_tag in ['VV', 'VV-I', 'VV-R', 'VA', 'VA-I', 'VA-R'] : 
                    index = index-1
                    current = tokens[index]
                else :
                    del auxiliary_idea[0]
                    del auxiliary_idea[0]
                    del auxiliary_idea[0]
                    current = None
            # S8 - Can Move Termination
            if current_tag in ['VV', 'VV-I', 'VV-R', 'VA', 'VA-I', 'VA-R'] :
                previous_tag = tokens[index+1]['tag']
                if previous_tag in ['ETN'] : 
                    if next_tag in ['NNB', 'XSN', 'NNG', 'NNP', 'NR', 'NP', 'ETN', 'JKG', 'MM', 'ETM', 'JKB', 'MAG', 'EC'] :
                        index = index-1
                        current = tokens[index]
                    else :
                        current = None
                elif previous_tag in ['ETM'] :
                    if next_tag in ['NNB', 'XSN', 'NNG', 'NNP', 'NR', 'NP', 'ETN', 'MAG', 'EC'] :
                        index = index-1
                        current = tokens[index]
                    else :
                        current = None
                else :
                    root_index = index+1
                    root_tag = tokens[root_index]['tag']
                    while root_tag not in ['ETN', 'ETM'] : 
                        root_index = root_index+1
                        root_tag = tokens[root_index]['tag']
                    if root_tag in ['ETN'] : 
                        if next_tag in ['NNB', 'XSN', 'NNG', 'NNP', 'NR', 'NP', 'ETN', 'JKG', 'MM', 'ETM', 'JKB', 'MAG', 'EC'] :
                            index = index-1
                            current = tokens[index]
                        else :
                            current = None
                    elif root_tag in ['ETM'] :
                        if next_tag in ['NNB', 'XSN', 'NNG', 'NNP', 'NR', 'NP', 'ETN', 'MAG', 'EC'] :
                            index = index-1
                            current = tokens[index]
                        else :
                            current = None
            # S9
            if current_tag in ['JKB'] :
                if next_tag in ['NNB', 'XSN', 'NNG', 'NNP', 'NR', 'NP', 'ETN'] : 
                    index = index-1
                    current = tokens[index]
                else :
                    del auxiliary_idea[0]
                    current = None
            # S10 - Can Move Termination
            if current_tag in ['MAG'] :
                current = None
            # S11
            if current_tag in ['JKG'] :
                if next_tag in ['NNB', 'XSN', 'NNG', 'NNP', 'NR', 'NP', 'ETN'] : 
                    index = index-1
                    current = tokens[index]
                else :
                    del auxiliary_idea[0]
                    current = None
            # S12 - Can Move Termination
            if current_tag in ['MM'] :
                if next_tag in ['NNB', 'XSN', 'NNG', 'NNP', 'NR', 'NP', 'ETN'] : 
                    index = index-1
                    current = tokens[index]
                else :
                    current = None
            # S13
            if current_tag in ['ETM'] :
                if next_tag in ['XSV', 'XSA', 'XSA-I', 'XSA-R', 'VV', 'VV-I', 'VV-R', 'VA', 'VA-I', 'VA-R', 'VX', 'VX-I', 'VX-R'] : 
                    index = index-1
                    current = tokens[index]
                else :
                    del auxiliary_idea[0]
                    current = None
            # S14
            if current_tag in ['XSV', 'XSA', 'XSA-I', 'XSA-R'] :
                nnext_tag = tokens[index-2]['tag']
                if next_tag in ['XR'] :
                    if next_tag in ['NNB', 'XSN', 'NNG', 'NNP', 'NR', 'NP', 'ETN'] :
                        auxiliary_idea.insert(0, tokens[index-1])
                        index = index-2
                        current = tokens[index]
                    else :
                        current = None
                else :
                    del auxiliary_idea[0]
                    del auxiliary_idea[0]
                    current = None
            
        if len(auxiliary_idea) != 0 :
            if sentence in auxiliary_ideas : 
                auxiliary_ideas[sentence]['auxiliary_idea'].append(auxiliary_idea)
            else :
                auxiliary_ideas[sentence] = {
                    'auxiliary_idea': [auxiliary_idea],
                    'tokens': tokens
                }
                
# find auxiliary idea string from pattern1 sentence
result1 = []
for key, value in auxiliary_ideas.items() : 
    sentence = key
    auxiliary_idea = value['auxiliary_idea']

    tmp = []
    for ai in auxiliary_idea : 
        start = ai[0]['start']
        end = ai[len(ai)-1]['start'] + ai[len(ai)-1]['len']

        tmp.append({
            'auxiliary_idea': sentence[start:end],
            'start': start,
            'end': end
        })

    auxiliary_idea = tmp

    result1.append([
        sentence, auxiliary_idea
    ])

# %%
# save auxiliary idea string
with open(PATH3+'/pattern1.json', 'w', encoding='utf-8') as file :
    json.dump(result1, file, indent='\t', ensure_ascii=False)

# %% [markdown]
# ### 패턴 2 '같은' 에 대해서 보조관념 추출

# %%
# choose sentences by pattern1
pattern2 = {}
for writing in writings : 
    for sentence in writing['sentences'] :
        if len(sentence) <= 0 : break
        if len(sentence) >= 1000 : break

        sentence = remove_ss(sentence)

        tokens = []
        if '같은' in sentence : 
            tokens = KIWI.analyze(sentence)[0][0]
        
        if len(tokens) != 0 :
            pattern2[sentence] = {'tokens': tokens_to_list_of_dict(tokens)}

# %%
# save pattern2 sentences
with open(PATH2+'/pattern2.json', 'w', encoding='utf-8') as file :
    json.dump(pattern2, file, indent='\t', ensure_ascii=False)

# %%
# load pattern1 sentences
pattern2 = None
with open(PATH2+'/pattern2.json', 'r', encoding='utf-8') as file : 
    pattern2 = json.load(file)

# %%
# extract auxiliary ideas from pattern1 sentences
auxiliary_ideas = {}

for key, value in pattern1.items() :
    sentence = key
    tokens = value['tokens']
    
    # find pos token of pattern2
    pattern_indexes = []
    for i in range(len(tokens)-1) :
        token1 = tokens[i]
        token2 = tokens[i+1]
        
        cond1 = token1['form'] == '같' and token1['tag'] == 'VA'
        cond2 = token2['form'] == '은' and token2['tag'] == 'ETM'

        if cond1 and cond2 :
            pattern_indexes.append(i)

    # find auxiliary idea pos token of pattern2
    for index in pattern_indexes :
        auxiliary_idea = []

        auxiliary_idea.insert(0, tokens[index+1])
        auxiliary_idea.insert(0, tokens[index])

        index = index-1
        current = tokens[index]
        if current['tag'] not in ['NNG', 'NNP', 'NR', 'NP', 'NNB'] : 
            current = None

        while current != None : 
            auxiliary_idea.insert(0, current)

            if index == 0 : 
                break

            current_tag = current['tag']
            next_tag = tokens[index-1]['tag']
            
            # S1
            if current_tag in ['NNB'] :
                if next_tag in ['JKG', 'MM', 'ETM'] : 
                    index = index-1
                    current = tokens[index]
                else :
                    del auxiliary_idea[0]
                    current = None
            # S2
            if current_tag in ['XSN'] :
                nnext_tag = tokens[index-2]['tag']
                if next_tag in ['XR'] :
                    if next_tag in ['NNB', 'XSN', 'NNG', 'NNP', 'NR', 'NP', 'ETN', 'JKG', 'MM', 'ETM'] :
                        auxiliary_idea.insert(0, tokens[index-1])
                        index = index-2
                        current = tokens[index]
                    else :
                        current = None
                else :
                    del auxiliary_idea[0]
                    current = None
            # S3 - Can Move Termination
            if current_tag in ['NNG', 'NNP', 'NR', 'NP'] :
                if next_tag in ['NNB', 'XSN', 'NNG', 'NNP', 'NR', 'NP', 'XPN', 'ETN', 'JKG', 'MM', 'ETM'] :
                    index = index-1
                    current = tokens[index]
                else :
                    current = None
            # S4
            if current_tag in ['ETN'] :
                if next_tag in ['VV', 'VV-I', 'VV-R', 'VA', 'VA-I', 'VA-R', 'VX', 'VX-I', 'VX-R'] : 
                    index = index-1
                    current = tokens[index]
                else :
                    del auxiliary_idea[0]
                    current = None
            # S5 - Can Move Termination
            if current_tag in ['XPN'] :
                if next_tag in ['NNB', 'XSN', 'NNG', 'NNP', 'NR', 'NP', 'ETN', 'JKG', 'MM', 'ETM'] : 
                    index = index-1
                    current = tokens[index]
                else :
                    current = None
            # S6
            if current_tag in ['VX', 'VX-I', 'VX-R'] :
                if next_tag in ['EC'] :
                    index = index-1
                    current = tokens[index]
                else :
                    del auxiliary_idea[0]
                    del auxiliary_idea[0]
                    current = None
            # S7 
            if current_tag in ['EC'] :
                if next_tag in ['VV', 'VV-I', 'VV-R', 'VA', 'VA-I', 'VA-R'] : 
                    index = index-1
                    current = tokens[index]
                else :
                    del auxiliary_idea[0]
                    del auxiliary_idea[0]
                    del auxiliary_idea[0]
                    current = None
            # S8 - Can Move Termination
            if current_tag in ['VV', 'VV-I', 'VV-R', 'VA', 'VA-I', 'VA-R'] :
                previous_tag = tokens[index+1]['tag']
                if previous_tag in ['ETN'] : 
                    if next_tag in ['NNB', 'XSN', 'NNG', 'NNP', 'NR', 'NP', 'ETN', 'JKG', 'MM', 'ETM', 'JKB', 'MAG', 'EC'] :
                        index = index-1
                        current = tokens[index]
                    else :
                        current = None
                elif previous_tag in ['ETM'] :
                    if next_tag in ['NNB', 'XSN', 'NNG', 'NNP', 'NR', 'NP', 'ETN', 'MAG', 'EC'] :
                        index = index-1
                        current = tokens[index]
                    else :
                        current = None
                else :
                    root_index = index+1
                    root_tag = tokens[root_index]['tag']
                    while root_tag not in ['ETN', 'ETM'] : 
                        root_index = root_index+1
                        root_tag = tokens[root_index]['tag']
                    if root_tag in ['ETN'] : 
                        if next_tag in ['NNB', 'XSN', 'NNG', 'NNP', 'NR', 'NP', 'ETN', 'JKG', 'MM', 'ETM', 'JKB', 'MAG', 'EC'] :
                            index = index-1
                            current = tokens[index]
                        else :
                            current = None
                    elif root_tag in ['ETM'] :
                        if next_tag in ['NNB', 'XSN', 'NNG', 'NNP', 'NR', 'NP', 'ETN', 'MAG', 'EC'] :
                            index = index-1
                            current = tokens[index]
                        else :
                            current = None
            # S9
            if current_tag in ['JKB'] :
                if next_tag in ['NNB', 'XSN', 'NNG', 'NNP', 'NR', 'NP', 'ETN'] : 
                    index = index-1
                    current = tokens[index]
                else :
                    del auxiliary_idea[0]
                    current = None
            # S10 - Can Move Termination
            if current_tag in ['MAG'] :
                current = None
            # S11
            if current_tag in ['JKG'] :
                if next_tag in ['NNB', 'XSN', 'NNG', 'NNP', 'NR', 'NP', 'ETN'] : 
                    index = index-1
                    current = tokens[index]
                else :
                    del auxiliary_idea[0]
                    current = None
            # S12 - Can Move Termination
            if current_tag in ['MM'] :
                if next_tag in ['NNB', 'XSN', 'NNG', 'NNP', 'NR', 'NP', 'ETN'] : 
                    index = index-1
                    current = tokens[index]
                else :
                    current = None
            # S13
            if current_tag in ['ETM'] :
                if next_tag in ['XSV', 'XSA', 'XSA-I', 'XSA-R', 'VV', 'VV-I', 'VV-R', 'VA', 'VA-I', 'VA-R', 'VX', 'VX-I', 'VX-R'] : 
                    index = index-1
                    current = tokens[index]
                else :
                    del auxiliary_idea[0]
                    current = None
            # S14
            if current_tag in ['XSV', 'XSA', 'XSA-I', 'XSA-R'] :
                nnext_tag = tokens[index-2]['tag']
                if next_tag in ['XR'] :
                    if next_tag in ['NNB', 'XSN', 'NNG', 'NNP', 'NR', 'NP', 'ETN'] :
                        auxiliary_idea.insert(0, tokens[index-1])
                        index = index-2
                        current = tokens[index]
                    else :
                        current = None
                else :
                    del auxiliary_idea[0]
                    del auxiliary_idea[0]
                    current = None
        
        if len(auxiliary_idea) != 0 :
            # print(sentence) # for log
            # print(auxiliary_idea) # for log
            # for t in tokens : 
            #     print(t)
            if sentence in auxiliary_ideas : 
                auxiliary_ideas[sentence]['auxiliary_idea'].append(auxiliary_idea)
            else :
                auxiliary_ideas[sentence] = {
                    'auxiliary_idea': [auxiliary_idea],
                    'tokens': tokens
                }        

# find auxiliary idea string from pattern2 sentence
result2 = []
for key, value in auxiliary_ideas.items() : 
    sentence = key
    auxiliary_idea = value['auxiliary_idea']

    tmp = []
    for ai in auxiliary_idea : 
        start = ai[0]['start']
        end = ai[len(ai)-1]['start'] + ai[len(ai)-1]['len']

        tmp.append({
            'auxiliary_idea': sentence[start:end],
            'start': start,
            'end': end
        })

    auxiliary_idea = tmp

    result2.append([
        sentence, auxiliary_idea
    ])

# %%
# save auxiliary idea string
with open(PATH3+'/pattern2.json', 'w', encoding='utf-8') as file :
    json.dump(result2, file, indent='\t', ensure_ascii=False)

# %% [markdown]
# ### 결과 통합

# %%
import os, json

result = []

for file_name in os.listdir('./data/extract_aux/') : 
    with open('./data/extract_aux/' + file_name, 'r', encoding='utf-8') as file :
        result.extend(json.load(file))

with open('./data/extract_aux/result.json', 'w', encoding='utf-8') as file :
    json.dump(result, file, indent='\t', ensure_ascii=False)
